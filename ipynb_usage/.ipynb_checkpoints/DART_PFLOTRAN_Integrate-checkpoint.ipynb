# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Overview" data-toc-modified-id="Overview-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Overview</a></span></li><li><span><a href="#Parameter-settings" data-toc-modified-id="Parameter-settings-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Parameter settings</a></span></li><li><span><a href="#PFLOTRAN-preparation-&amp;-spin-up" data-toc-modified-id="PFLOTRAN-preparation-&amp;-spin-up-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>PFLOTRAN preparation &amp; spin-up</a></span><ul class="toc-item"><li><span><a href="#Generate-PFLOTRAN.in-and-parameter.h5" data-toc-modified-id="Generate-PFLOTRAN.in-and-parameter.h5-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Generate <code>PFLOTRAN.in</code> and <code>parameter.h5</code></a></span></li><li><span><a href="#Model-spin-up" data-toc-modified-id="Model-spin-up-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Model spin-up</a></span></li></ul></li><li><span><a href="#DART-files-preparation" data-toc-modified-id="DART-files-preparation-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>DART files preparation</a></span><ul class="toc-item"><li><span><a href="#Generate-the-templates-for-DART-generic-variable-quantity-files" data-toc-modified-id="Generate-the-templates-for-DART-generic-variable-quantity-files-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Generate the templates for DART generic variable quantity files</a></span></li><li><span><a href="#Generate-prior.nc-from-the-model-spin-up" data-toc-modified-id="Generate-prior.nc-from-the-model-spin-up-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Generate <code>prior.nc</code> from the model spin-up</a></span></li><li><span><a href="#Generate-input.nml" data-toc-modified-id="Generate-input.nml-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Generate <code>input.nml</code></a></span></li><li><span><a href="#Convert-observation-to-DART-observation-format" data-toc-modified-id="Convert-observation-to-DART-observation-format-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Convert observation to DART observation format</a></span></li><li><span><a href="#Run-check_model_mod" data-toc-modified-id="Run-check_model_mod-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Run <code>check_model_mod</code></a></span></li></ul></li><li><span><a href="#(TODO)-Run-DART-and-PFLOTRAN" data-toc-modified-id="(TODO)-Run-DART-and-PFLOTRAN-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>(TODO) Run DART and PFLOTRAN</a></span></li></ul></div>

# %% [markdown]
# # Overview
# - The objective of this notebook.
# - Data Assimilation Research Testbed (DART) background
# - Include the links for the below sections

# %% [markdown]
# # Parameter settings

# %%
import re
import pickle

# %%
# Directories
obs_kind_dir    = '../obs_kind/'
obs_type_dir    = '../obs_type/'
obs_convert_dir = '../obs_converter/'
utils_dir       = '../utils/'
work_dir        = '../work/'
pflotran_in_dir = '../pflotran_input/'
pflotran_out_dir= '../pflotran_output/'
dart_data_dir   = '../dart_inout/'

# DART file names
def_obs_kind   = obs_kind_dir+'DEFAULT_obs_kind_mod.f90'
obs_type       = obs_type_dir+'obs_def_pflotran_mod.f90'
input_nml      = work_dir+'input.nml'
input_nml_dict = work_dir+'inputnml.p'

# PFLOTRAN file names
pflotran_sh   = utils_dir+'pflotran.sh'
pflotran_exe  = '/Users/jian449/Codes/pflotran/src/pflotran/pflotran'
pflotran_in   = pflotran_in_dir+'pflotran.in'
pflotran_para = pflotran_in_dir+'parameter.h5'
pflotran_out  = pflotran_out_dir+'R[ENS].h5'

# Data file names, including observations and model input/output
obs_original = pflotran_in_dir+'temperature.csv'
obs_nc       = pflotran_in_dir+'obs_pflotran.nc'
obs_dart     = dart_data_dir+'obs_seq_pflotran.out'
dart_prior_nc= dart_data_dir+'prior_R[ENS].nc'

# Some shell scripts or executable files
compile_convert_nc      = work_dir+'dart_seq_convert.csh'
compile_model_check_mod = work_dir+'check_model_mod.csh'
run_filter              = work_dir+'run_filter.csh'
advance_model           = work_dir+'advance_model.csh'
convert_nc              = work_dir+'convert_nc'

# MPI settings
mpi_exe = '/usr/local/bin/mpirun'
ncore   = 1

# Utility file names
csv_to_nc          = utils_dir+'csv2nc.py'
to_dartqty         = utils_dir+'list2dartqty.py'
obs_type_qty_ind   = utils_dir+'obs_type_qty_ind.txt'
prep_pflotran_in   = utils_dir+'prepare_pflotran_inpara.py'
prep_convert_nc    = utils_dir+'prepare_convert_nc.py'
prep_prior_nc      = utils_dir+'prepare_prior_nc.py'
prep_inputnml      = utils_dir+'prepare_input_nml.py'
prep_convertncnml  = utils_dir+'prepare_convertnc_nml.py'

# %%
# Data assimilation configurations
# More need to be added...
# And later on, these DA setting can be saved in a txt or pickel file for further loading
obs_timestep = 300.0  # second
obs_error    = 0.1    # observation error
spinup       = 1      # whether model spinup
nens         = 30     # number of ensembles

# Specify PFLOTRAN variables used as observation and state vector/parameters in DART
obs_var_set = ['TEMPERATURE']
para_set    = ['FLOW_FLUX','POROSITY','THERMAL_CONDUCTIVITY']
# state_set   = ['LIQUID_SATURATION','LIQUID_PRESSURE', 'TEST_VARIABLE', 'TEST_VARIABLEAAA'
pflotran_parastate_set = obs_var_set + para_set

# %% [markdown]
# # PFLOTRAN preparation & spin-up
# **Here, we use Kewei's 1D thermal model as an example for generating PFLOTRAN input card and parameter.h5.**
#
# In this section, the following procedures are conducted for PFLOTRAN:
# - generate ```PFLOTRAN.in``` (for 1D thermal model, check Kewei's code)
# - generate the parameter files in HDF 5, ```parameter.h5``` (for 1D thermal model, check Kewei's code)
# - conduct model spin-up and generate PFLOTRAN output in HDF 5 format, ```PFLOTRAN.h5```

# %% [markdown]
# ## Generate ```PFLOTRAN.in``` and ```parameter.h5```
# - Run: ```prepare_pflotran_inpara.py```
# - Code input arguments:
#     - filename for ```pflotran.in```
#     - filename for ```parameter.h5```
#     - data assimilation settings (**to be revised later on**): observation timestep, observation error, number of ensemble, whether it is spinup

# %%
# %%script bash -s "$prep_pflotran_in" "$pflotran_in" "$pflotran_para" "$obs_timestep" "$obs_error" "$nens" "$spinup"
# python $1 $2 $3 $4 $5 $6 $7
# Out:
# Finished generating the input card for PFLOTRAN...
# Finished generating the DBASE for PFLOTRAN...

# %% [markdown]
# ## Model spin-up
# Take in the ```pflotran.in``` and ```parameter.h5``` files and conduct the model spin-up by running ```pflotran.sh``` file. The ```pflotran.sh``` is a simple shell script executing ensemble simulation of PFLOTRAN by using MPI.

# %%
# %%script bash -s "$pflotran_sh" "$pflotran_exe" "$pflotran_in" "$pflotran_out_dir" "$nens" "$mpi_exe" "$ncore"
# echo $3
# $1 $2 $3 $4 $5 $6 $7
# Out:
# ../pflotran_input/pflotran.in
#  here
#           30
# ------------------------------ Provenance --------------------------------------
# pflotran_compile_date_time = unknown
# pflotran_compile_user = unknown
# pflotran_compile_hostname = unknown
# pflotran_changeset = unknown
# pflotran_status = unknown
# petsc_changeset = unknown
# petsc_status = unknown
# --------------------------------------------------------------------------------
#  "grid_structured_type" set to default value.
#  Opening hdf5 file: ../pflotran_input/parameter.h5
#  pflotran card:: TIMESTEPPER
#  pflotran card:: TIMESTEPPER
#  pflotran card:: NEWTON_SOLVER
#  pflotran card:: LINEAR_SOLVER
#  pflotran card:: NEWTON_SOLVER
#  pflotran card:: LINEAR_SOLVER
#  pflotran card:: GRID
#  pflotran card:: FLUID_PROPERTY
#  "FLUID_PROPERTY,diffusion_coeffient units" set to default value.
#  pflotran card:: MATERIAL_PROPERTY
#    Name :: Alluvium
#  "MATERIAL_PROPERTY,rock density units" set to default value.
#  "MATERIAL_PROPERTY,specific heat units" set to default value.
#  "MATERIAL_PROPERTY,dry thermal conductivity units" set to default value.
#  "MATERIAL_PROPERTY,wet thermal conductivity units" set to default value.
#  pflotran card:: CHARACTERISTIC_CURVES
#    Name :: default
#  WARNING: A default Saturation Function has been chosen in CHARACTERISTIC_CURVES(default),.
#  WARNING: A default Relative Permeability Function has been chosen in CHARACTERISTIC_CURVES(default),.
#  WARNING: A default Relative Permeability Function has been chosen in CHARACTERISTIC_CURVES(default),.
#  pflotran card:: OUTPUT
#  pflotran card:: TIME
#  pflotran card:: REGION
#  all
#  pflotran card:: REGION
#  top
#  pflotran card:: REGION
#  bottom
#  pflotran card:: DBASE_FILENAME
#  pflotran card:: MINIMUM_HYDROSTATIC_PRESSURE
#  "Minimum Hydrostatic Pressure units" set to default value.
#  pflotran card:: FLOW_CONDITION
#  initial
#  WARNING: "iphase" not set in condition; set to 1
#  pflotran card:: FLOW_CONDITION
#  flow_top
#  WARNING: "iphase" not set in condition; set to 1
#  pflotran card:: FLOW_CONDITION
#  flow_bottom
#  WARNING: "iphase" not set in condition; set to 1
#  pflotran card:: INITIAL_CONDITION
#  pflotran card:: BOUNDARY_CONDITION
#  pflotran card:: BOUNDARY_CONDITION
#  pflotran card:: STRATA
#  pflotran card:: END_SUBSURFACE
#  Domain Bounds (x y z):
#      0.0000000000E+00  0.0000000000E+00 -6.4000000000E-01
#      1.0000000000E+00  1.0000000000E+00  0.0000000000E+00
#  Extent of Gridded Domain
#   X: 0.0000000000000000 - 1.0000000000000000
#   Y: 0.0000000000000000 - 1.0000000000000000
#   Z: -0.64000000000000001 - 0.0000000000000000
#
#  Default HDF5 method is used in Initialization
#
#  Requested processors and decomposition =     1, npx,y,z=   -1  -1  -1
#  Actual decomposition: npx,y,z=    1   1   1
#
#    Beginning setup of FLOW SNES
#  number of dofs =   2, number of phases =   1
#  mode = TH: p, T
#    Finished setting up FLOW SNES
#
# FLOW Time Stepper
#                  acceleration: on
#        acceleration threshold: 8
#        number of ramp entries: 8
#                 ramp entry #1: 2.0000
#                 ramp entry #2: 2.0000
#                 ramp entry #3: 2.0000
#                 ramp entry #4: 2.0000
#                 ramp entry #5: 2.0000
#                 ramp entry #6: 1.8000
#                 ramp entry #7: 1.6000
#                 ramp entry #8: 1.4000
#                 ramp entry #9: 1.2000
#                ramp entry #10: 1.0000
#                ramp entry #11: 1.0000
#                ramp entry #12: 1.0000
#                ramp entry #13: 1.0000
#       maximum number of steps: 999999
# constant time steps threshold: 5
#        maximum number of cuts: 50
#              reduction factor: 5.000000E-01
#         maximum growth factor: 2.000000E+00
#
# FLOW Newton Solver
#                          atol: 1.000000E-50
#                          rtol: 1.000000E-50
#                          stol: 1.000000E-60
#                          dtol: 1.000000E+20
#                       maxnorm: 1.000000E+20
#                     inftolres: -9.990000E+02
#                     inftolupd: 1.000000E+00
#                  inftolrelupd: -9.990000E+02
#                  inftolsclres: -9.990000E+02
#                      max iter: 20
#                      min iter: 1
#                          maxf: 10000
#                   matrix type: baij
#          precond. matrix type: baij
#                inexact newton: off
#             print convergence: on
#    print detailed convergence: off
#           check infinity norm: on
#
# FLOW Linear Solver
#                        solver: bcgs
#                preconditioner: ilu
#                          atol: 1.000000E-50
#                          rtol: 1.000000E-05
#                          dtol: 1.000000E+04
#             maximum iteration: 10000
#  --> creating hdf5 output file: R1.h5
#        0.00 Seconds to write HDF5 file.
#
#    Finished Initialization
#
# == TH FLOW =====================================================================
#   0 2r: 1.53E+03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.41E+03 iu: 0.00E+00 rsn:   0
#   1 2r: 5.23E-04 2x: 1.23E+06 2u: 3.93E+05 ir: 3.64E-04 iu: 4.92E+04 rsn:   0
#   2 2r: 1.16E-07 2x: 1.23E+06 2u: 2.38E-01 ir: 8.04E-08 iu: 7.44E-02 rsn: itol_upd
#
#  Step      1 Time=  3.60000E+03 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   2 [       2] linear =     2 [         2] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            2  /            2
#   --> SNES Residual:   1.158024E-07  1.809413E-09  8.038448E-08
#   --> max chng: dpmx=   4.9150E+04 dtmpmx=   1.5371E-01
#
#
# == TH FLOW =====================================================================
#   0 2r: 8.71E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 6.05E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.03E-04 2x: 1.23E+06 2u: 1.62E+00 ir: 9.75E-05 iu: 2.11E-01 rsn: itol_upd
#
#  Step      2 Time=  7.20000E+03 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       3] linear =     1 [         3] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.029940E-04  1.609281E-06  9.752941E-05
#   --> max chng: dpmx=   2.1065E-01 dtmpmx=   2.0639E-01
#
#
# == TH FLOW =====================================================================
#   0 2r: 2.18E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 2.16E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.12E-07 2x: 1.23E+06 2u: 1.41E-01 ir: 8.10E-08 iu: 5.49E-02 rsn: itol_upd
#
#  Step      3 Time=  1.08000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       4] linear =     1 [         4] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.120154E-07  1.750241E-09  8.097998E-08
#   --> max chng: dpmx=   1.9916E-02 dtmpmx=   5.4876E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 2.02E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 2.01E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 9.50E-08 2x: 1.23E+06 2u: 1.76E-01 ir: 8.39E-08 iu: 5.44E-02 rsn: itol_upd
#
#  Step      4 Time=  1.44000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       5] linear =     1 [         5] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   9.498262E-08  1.484103E-09  8.385934E-08
#   --> max chng: dpmx=   3.7354E-02 dtmpmx=   5.4410E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.84E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.77E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 3.91E-07 2x: 1.23E+06 2u: 2.56E-01 ir: 3.63E-07 iu: 5.72E-02 rsn: itol_upd
#
#  Step      5 Time=  1.80000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       6] linear =     1 [         6] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   3.910265E-07  6.109790E-09  3.633948E-07
#   --> max chng: dpmx=   5.7167E-02 dtmpmx=   4.8766E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.62E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.55E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 4.05E-07 2x: 1.23E+06 2u: 2.88E-01 ir: 3.79E-07 iu: 6.37E-02 rsn: itol_upd
#
#  Step      6 Time=  2.16000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       7] linear =     1 [         7] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   4.046798E-07  6.323121E-09  3.794206E-07
#   --> max chng: dpmx=   6.3736E-02 dtmpmx=   4.3084E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.33E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.02E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.24E-06 2x: 1.23E+06 2u: 3.73E-01 ir: 1.17E-06 iu: 7.61E-02 rsn: itol_upd
#
#  Step      7 Time=  2.52000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       8] linear =     1 [         8] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.238738E-06  1.935528E-08  1.174037E-06
#   --> max chng: dpmx=   7.6118E-02 dtmpmx=   3.4418E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 6.24E-04 2x: 0.00E+00 2u: 0.00E+00 ir: 4.25E-04 iu: 0.00E+00 rsn:   0
#   1 2r: 6.09E-07 2x: 1.23E+06 2u: 3.28E-01 ir: 5.77E-07 iu: 6.48E-02 rsn: itol_upd
#
#  Step      8 Time=  2.88000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       9] linear =     1 [         9] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   6.085612E-07  9.508768E-09  5.770949E-07
#   --> max chng: dpmx=   6.4808E-02 dtmpmx=   2.7808E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.25E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 9.36E-04 iu: 0.00E+00 rsn:   0
#   1 2r: 1.18E-06 2x: 1.23E+06 2u: 3.68E-01 ir: 1.12E-06 iu: 6.33E-02 rsn: itol_upd
#
#  Step      9 Time=  3.24000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      10] linear =     1 [        10] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.180736E-06  1.844900E-08  1.119394E-06
#   --> max chng: dpmx=   6.3294E-02 dtmpmx=   2.3144E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 2.21E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 2.05E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.16E-06 2x: 1.23E+06 2u: 3.61E-01 ir: 1.10E-06 iu: 5.66E-02 rsn: itol_upd
#
#  Step     10 Time=  3.60000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      11] linear =     1 [        11] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.162481E-06  1.816377E-08  1.098789E-06
#   --> max chng: dpmx=   5.6588E-02 dtmpmx=   5.3581E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 3.50E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 3.37E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.56E-06 2x: 1.23E+06 2u: 3.93E-01 ir: 1.46E-06 iu: 8.96E-02 rsn: itol_upd
#
#  Step     11 Time=  3.96000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      12] linear =     1 [        12] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.557442E-06  2.433503E-08  1.456253E-06
#   --> max chng: dpmx=   5.4358E-02 dtmpmx=   8.9567E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 3.86E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 3.73E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.61E-06 2x: 1.23E+06 2u: 4.02E-01 ir: 1.50E-06 iu: 1.01E-01 rsn: itol_upd
#
#  Step     12 Time=  4.32000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      13] linear =     1 [        13] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.613452E-06  2.521018E-08  1.498145E-06
#   --> max chng: dpmx=   4.9999E-02 dtmpmx=   1.0091E-01
#
#  --> appending to hdf5 output file: R1.h5
#        0.00 Seconds to write HDF5 file.
#   --> Dump checkpoint file: R1-restart.chk
#        Seconds to write to checkpoint file:       0.00
#
# FLOW TS BE steps =     12 newton =       13 linear =         13 cuts =      0
# FLOW TS BE Wasted Linear Iterations = 0
# FLOW TS BE SNES time = 0.0 seconds
#
#  Wall Clock Time:  1.0172E-01 [sec]   1.6954E-03 [min]   2.8257E-05 [hr]
#  "grid_structured_type" set to default value.
#  Opening hdf5 file: ../pflotran_input/parameter.h5
#  pflotran card:: TIMESTEPPER
#  pflotran card:: TIMESTEPPER
#  pflotran card:: NEWTON_SOLVER
#  pflotran card:: LINEAR_SOLVER
#  pflotran card:: NEWTON_SOLVER
#  pflotran card:: LINEAR_SOLVER
#  pflotran card:: GRID
#  pflotran card:: FLUID_PROPERTY
#  "FLUID_PROPERTY,diffusion_coeffient units" set to default value.
#  pflotran card:: MATERIAL_PROPERTY
#    Name :: Alluvium
#  "MATERIAL_PROPERTY,rock density units" set to default value.
#  "MATERIAL_PROPERTY,specific heat units" set to default value.
#  "MATERIAL_PROPERTY,dry thermal conductivity units" set to default value.
#  "MATERIAL_PROPERTY,wet thermal conductivity units" set to default value.
#  pflotran card:: CHARACTERISTIC_CURVES
#    Name :: default
#  WARNING: A default Saturation Function has been chosen in CHARACTERISTIC_CURVES(default),.
#  WARNING: A default Relative Permeability Function has been chosen in CHARACTERISTIC_CURVES(default),.
#  WARNING: A default Relative Permeability Function has been chosen in CHARACTERISTIC_CURVES(default),.
#  pflotran card:: OUTPUT
#  pflotran card:: TIME
#  pflotran card:: REGION
#  all
#  pflotran card:: REGION
#  top
#  pflotran card:: REGION
#  bottom
#  pflotran card:: DBASE_FILENAME
#  pflotran card:: MINIMUM_HYDROSTATIC_PRESSURE
#  "Minimum Hydrostatic Pressure units" set to default value.
#  pflotran card:: FLOW_CONDITION
#  initial
#  WARNING: "iphase" not set in condition; set to 1
#  pflotran card:: FLOW_CONDITION
#  flow_top
#  WARNING: "iphase" not set in condition; set to 1
#  pflotran card:: FLOW_CONDITION
#  flow_bottom
#  WARNING: "iphase" not set in condition; set to 1
#  pflotran card:: INITIAL_CONDITION
#  pflotran card:: BOUNDARY_CONDITION
#  pflotran card:: BOUNDARY_CONDITION
#  pflotran card:: STRATA
#  pflotran card:: END_SUBSURFACE
#  Domain Bounds (x y z):
#      0.0000000000E+00  0.0000000000E+00 -6.4000000000E-01
#      1.0000000000E+00  1.0000000000E+00  0.0000000000E+00
#  Extent of Gridded Domain
#   X: 0.0000000000000000 - 1.0000000000000000
#   Y: 0.0000000000000000 - 1.0000000000000000
#   Z: -0.64000000000000001 - 0.0000000000000000
#
#  Default HDF5 method is used in Initialization
#
#  Requested processors and decomposition =     1, npx,y,z=   -1  -1  -1
#  Actual decomposition: npx,y,z=    1   1   1
#
#    Beginning setup of FLOW SNES
#  number of dofs =   2, number of phases =   1
#  mode = TH: p, T
#    Finished setting up FLOW SNES
#
# FLOW Time Stepper
#                  acceleration: on
#        acceleration threshold: 8
#        number of ramp entries: 8
#                 ramp entry #1: 2.0000
#                 ramp entry #2: 2.0000
#                 ramp entry #3: 2.0000
#                 ramp entry #4: 2.0000
#                 ramp entry #5: 2.0000
#                 ramp entry #6: 1.8000
#                 ramp entry #7: 1.6000
#                 ramp entry #8: 1.4000
#                 ramp entry #9: 1.2000
#                ramp entry #10: 1.0000
#                ramp entry #11: 1.0000
#                ramp entry #12: 1.0000
#                ramp entry #13: 1.0000
#       maximum number of steps: 999999
# constant time steps threshold: 5
#        maximum number of cuts: 50
#              reduction factor: 5.000000E-01
#         maximum growth factor: 2.000000E+00
#
# FLOW Newton Solver
#                          atol: 1.000000E-50
#                          rtol: 1.000000E-50
#                          stol: 1.000000E-60
#                          dtol: 1.000000E+20
#                       maxnorm: 1.000000E+20
#                     inftolres: -9.990000E+02
#                     inftolupd: 1.000000E+00
#                  inftolrelupd: -9.990000E+02
#                  inftolsclres: -9.990000E+02
#                      max iter: 20
#                      min iter: 1
#                          maxf: 10000
#                   matrix type: baij
#          precond. matrix type: baij
#                inexact newton: off
#             print convergence: on
#    print detailed convergence: off
#           check infinity norm: on
#
# FLOW Linear Solver
#                        solver: bcgs
#                preconditioner: ilu
#                          atol: 1.000000E-50
#                          rtol: 1.000000E-05
#                          dtol: 1.000000E+04
#             maximum iteration: 10000
#  --> creating hdf5 output file: R2.h5
#        0.00 Seconds to write HDF5 file.
#
#    Finished Initialization
#
# == TH FLOW =====================================================================
#   0 2r: 1.53E+03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.41E+03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.36E-03 2x: 1.23E+06 2u: 3.93E+05 ir: 9.79E-04 iu: 4.93E+04 rsn:   0
#   2 2r: 9.71E-07 2x: 1.23E+06 2u: 5.24E-01 ir: 6.37E-07 iu: 2.01E-01 rsn: itol_upd
#
#  Step      1 Time=  3.60000E+03 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   2 [       2] linear =     2 [         2] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            2  /            2
#   --> SNES Residual:   9.706791E-07  1.516686E-08  6.365049E-07
#   --> max chng: dpmx=   4.9312E+04 dtmpmx=   1.5699E-01
#
#
# == TH FLOW =====================================================================
#   0 2r: 6.91E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 5.36E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 9.26E-05 2x: 1.23E+06 2u: 1.63E+00 ir: 8.76E-05 iu: 2.28E-01 rsn: itol_upd
#
#  Step      2 Time=  7.20000E+03 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       3] linear =     1 [         3] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   9.264373E-05  1.447558E-06  8.756194E-05
#   --> max chng: dpmx=   2.2777E-01 dtmpmx=   1.8464E-01
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.72E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.70E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.95E-07 2x: 1.23E+06 2u: 3.83E-01 ir: 1.59E-07 iu: 1.11E-01 rsn: itol_upd
#
#  Step      3 Time=  1.08000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       4] linear =     1 [         4] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.946597E-07  3.041557E-09  1.591105E-07
#   --> max chng: dpmx=   1.1085E-01 dtmpmx=   5.5518E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.61E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.60E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.82E-07 2x: 1.23E+06 2u: 5.92E-01 ir: 1.63E-07 iu: 1.65E-01 rsn: itol_upd
#
#  Step      4 Time=  1.44000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       5] linear =     1 [         5] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.820853E-07  2.845084E-09  1.626507E-07
#   --> max chng: dpmx=   1.6483E-01 dtmpmx=   5.5307E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.47E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.41E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 4.16E-07 2x: 1.23E+06 2u: 8.28E-01 ir: 3.70E-07 iu: 2.12E-01 rsn: itol_upd
#
#  Step      5 Time=  1.80000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       6] linear =     1 [         6] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   4.164655E-07  6.507274E-09  3.699049E-07
#   --> max chng: dpmx=   2.1162E-01 dtmpmx=   4.9354E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.30E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.23E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 4.31E-07 2x: 1.23E+06 2u: 9.76E-01 ir: 3.95E-07 iu: 2.38E-01 rsn: itol_upd
#
#  Step      6 Time=  2.16000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       7] linear =     1 [         7] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   4.313084E-07  6.739194E-09  3.948274E-07
#   --> max chng: dpmx=   2.3759E-01 dtmpmx=   4.4889E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.08E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 8.10E-04 iu: 0.00E+00 rsn:   0
#   1 2r: 1.24E-06 2x: 1.23E+06 2u: 1.15E+00 ir: 1.17E-06 iu: 2.57E-01 rsn: itol_upd
#
#  Step      7 Time=  2.52000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       8] linear =     1 [         8] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.239463E-06  1.936661E-08  1.173244E-06
#   --> max chng: dpmx=   2.5661E-01 dtmpmx=   3.9779E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 5.26E-04 2x: 0.00E+00 2u: 0.00E+00 ir: 3.98E-04 iu: 0.00E+00 rsn:   0
#   1 2r: 6.47E-07 2x: 1.23E+06 2u: 1.14E+00 ir: 6.14E-07 iu: 2.32E-01 rsn: itol_upd
#
#  Step      8 Time=  2.88000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       9] linear =     1 [         9] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   6.472217E-07  1.011284E-08  6.140073E-07
#   --> max chng: dpmx=   2.3186E-01 dtmpmx=   3.5634E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.01E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 7.42E-04 iu: 0.00E+00 rsn:   0
#   1 2r: 1.23E-06 2x: 1.23E+06 2u: 1.13E+00 ir: 1.16E-06 iu: 2.02E-01 rsn: itol_upd
#
#  Step      9 Time=  3.24000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      10] linear =     1 [        10] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.226987E-06  1.917167E-08  1.163011E-06
#   --> max chng: dpmx=   2.0201E-01 dtmpmx=   3.2233E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.76E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.63E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.23E-06 2x: 1.23E+06 2u: 9.90E-01 ir: 1.16E-06 iu: 1.65E-01 rsn: itol_upd
#
#  Step     10 Time=  3.60000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      11] linear =     1 [        11] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.232226E-06  1.925353E-08  1.156012E-06
#   --> max chng: dpmx=   1.6544E-01 dtmpmx=   5.5175E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 2.79E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 2.68E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.67E-06 2x: 1.23E+06 2u: 8.17E-01 ir: 1.51E-06 iu: 1.33E-01 rsn: itol_upd
#
#  Step     11 Time=  3.96000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      12] linear =     1 [        12] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.667331E-06  2.605204E-08  1.507873E-06
#   --> max chng: dpmx=   1.3307E-01 dtmpmx=   9.1657E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 3.07E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 2.97E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.73E-06 2x: 1.23E+06 2u: 6.71E-01 ir: 1.53E-06 iu: 1.03E-01 rsn: itol_upd
#
#  Step     12 Time=  4.32000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      13] linear =     1 [        13] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.734472E-06  2.710113E-08  1.533026E-06
#   --> max chng: dpmx=   9.9962E-02 dtmpmx=   1.0289E-01
#
#  --> appending to hdf5 output file: R2.h5
#        0.00 Seconds to write HDF5 file.
#   --> Dump checkpoint file: R2-restart.chk
#        Seconds to write to checkpoint file:       0.00
#
# FLOW TS BE steps =     12 newton =       13 linear =         13 cuts =      0
# FLOW TS BE Wasted Linear Iterations = 0
# FLOW TS BE SNES time = 0.0 seconds
#
#  Wall Clock Time:  5.6601E-02 [sec]   9.4335E-04 [min]   1.5723E-05 [hr]
#  "grid_structured_type" set to default value.
#  Opening hdf5 file: ../pflotran_input/parameter.h5
#  pflotran card:: TIMESTEPPER
#  pflotran card:: TIMESTEPPER
#  pflotran card:: NEWTON_SOLVER
#  pflotran card:: LINEAR_SOLVER
#  pflotran card:: NEWTON_SOLVER
#  pflotran card:: LINEAR_SOLVER
#  pflotran card:: GRID
#  pflotran card:: FLUID_PROPERTY
#  "FLUID_PROPERTY,diffusion_coeffient units" set to default value.
#  pflotran card:: MATERIAL_PROPERTY
#    Name :: Alluvium
#  "MATERIAL_PROPERTY,rock density units" set to default value.
#  "MATERIAL_PROPERTY,specific heat units" set to default value.
#  "MATERIAL_PROPERTY,dry thermal conductivity units" set to default value.
#  "MATERIAL_PROPERTY,wet thermal conductivity units" set to default value.
#  pflotran card:: CHARACTERISTIC_CURVES
#    Name :: default
#  WARNING: A default Saturation Function has been chosen in CHARACTERISTIC_CURVES(default),.
#  WARNING: A default Relative Permeability Function has been chosen in CHARACTERISTIC_CURVES(default),.
#  WARNING: A default Relative Permeability Function has been chosen in CHARACTERISTIC_CURVES(default),.
#  pflotran card:: OUTPUT
#  pflotran card:: TIME
#  pflotran card:: REGION
#  all
#  pflotran card:: REGION
#  top
#  pflotran card:: REGION
#  bottom
#  pflotran card:: DBASE_FILENAME
#  pflotran card:: MINIMUM_HYDROSTATIC_PRESSURE
#  "Minimum Hydrostatic Pressure units" set to default value.
#  pflotran card:: FLOW_CONDITION
#  initial
#  WARNING: "iphase" not set in condition; set to 1
#  pflotran card:: FLOW_CONDITION
#  flow_top
#  WARNING: "iphase" not set in condition; set to 1
#  pflotran card:: FLOW_CONDITION
#  flow_bottom
#  WARNING: "iphase" not set in condition; set to 1
#  pflotran card:: INITIAL_CONDITION
#  pflotran card:: BOUNDARY_CONDITION
#  pflotran card:: BOUNDARY_CONDITION
#  pflotran card:: STRATA
#  pflotran card:: END_SUBSURFACE
#  Domain Bounds (x y z):
#      0.0000000000E+00  0.0000000000E+00 -6.4000000000E-01
#      1.0000000000E+00  1.0000000000E+00  0.0000000000E+00
#  Extent of Gridded Domain
#   X: 0.0000000000000000 - 1.0000000000000000
#   Y: 0.0000000000000000 - 1.0000000000000000
#   Z: -0.64000000000000001 - 0.0000000000000000
#
#  Default HDF5 method is used in Initialization
#
#  Requested processors and decomposition =     1, npx,y,z=   -1  -1  -1
#  Actual decomposition: npx,y,z=    1   1   1
#
#    Beginning setup of FLOW SNES
#  number of dofs =   2, number of phases =   1
#  mode = TH: p, T
#    Finished setting up FLOW SNES
#
# FLOW Time Stepper
#                  acceleration: on
#        acceleration threshold: 8
#        number of ramp entries: 8
#                 ramp entry #1: 2.0000
#                 ramp entry #2: 2.0000
#                 ramp entry #3: 2.0000
#                 ramp entry #4: 2.0000
#                 ramp entry #5: 2.0000
#                 ramp entry #6: 1.8000
#                 ramp entry #7: 1.6000
#                 ramp entry #8: 1.4000
#                 ramp entry #9: 1.2000
#                ramp entry #10: 1.0000
#                ramp entry #11: 1.0000
#                ramp entry #12: 1.0000
#                ramp entry #13: 1.0000
#       maximum number of steps: 999999
# constant time steps threshold: 5
#        maximum number of cuts: 50
#              reduction factor: 5.000000E-01
#         maximum growth factor: 2.000000E+00
#
# FLOW Newton Solver
#                          atol: 1.000000E-50
#                          rtol: 1.000000E-50
#                          stol: 1.000000E-60
#                          dtol: 1.000000E+20
#                       maxnorm: 1.000000E+20
#                     inftolres: -9.990000E+02
#                     inftolupd: 1.000000E+00
#                  inftolrelupd: -9.990000E+02
#                  inftolsclres: -9.990000E+02
#                      max iter: 20
#                      min iter: 1
#                          maxf: 10000
#                   matrix type: baij
#          precond. matrix type: baij
#                inexact newton: off
#             print convergence: on
#    print detailed convergence: off
#           check infinity norm: on
#
# FLOW Linear Solver
#                        solver: bcgs
#                preconditioner: ilu
#                          atol: 1.000000E-50
#                          rtol: 1.000000E-05
#                          dtol: 1.000000E+04
#             maximum iteration: 10000
#  --> creating hdf5 output file: R3.h5
#        0.00 Seconds to write HDF5 file.
#
#    Finished Initialization
#
# == TH FLOW =====================================================================
#   0 2r: 1.53E+03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.41E+03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.17E-03 2x: 1.23E+06 2u: 3.93E+05 ir: 8.37E-04 iu: 4.93E+04 rsn:   0
#   2 2r: 8.66E-07 2x: 1.23E+06 2u: 3.32E-01 ir: 5.94E-07 iu: 1.36E-01 rsn: itol_upd
#
#  Step      1 Time=  3.60000E+03 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   2 [       2] linear =     2 [         2] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            2  /            2
#   --> SNES Residual:   8.657928E-07  1.352801E-08  5.935175E-07
#   --> max chng: dpmx=   4.9275E+04 dtmpmx=   1.5373E-01
#
#
# == TH FLOW =====================================================================
#   0 2r: 6.17E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 5.36E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 8.79E-05 2x: 1.23E+06 2u: 1.55E+00 ir: 8.31E-05 iu: 2.14E-01 rsn: itol_upd
#
#  Step      2 Time=  7.20000E+03 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       3] linear =     1 [         3] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   8.791294E-05  1.373640E-06  8.311341E-05
#   --> max chng: dpmx=   2.1409E-01 dtmpmx=   1.7543E-01
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.37E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.35E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.67E-07 2x: 1.23E+06 2u: 2.47E-01 ir: 1.32E-07 iu: 7.38E-02 rsn: itol_upd
#
#  Step      3 Time=  1.08000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       4] linear =     1 [         4] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.672939E-07  2.613967E-09  1.315629E-07
#   --> max chng: dpmx=   7.3817E-02 dtmpmx=   5.3628E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.30E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.30E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.61E-07 2x: 1.23E+06 2u: 3.85E-01 ir: 1.43E-07 iu: 1.13E-01 rsn: itol_upd
#
#  Step      4 Time=  1.44000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       5] linear =     1 [         5] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.608153E-07  2.512739E-09  1.432108E-07
#   --> max chng: dpmx=   1.1281E-01 dtmpmx=   5.4945E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.21E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.14E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 3.72E-07 2x: 1.23E+06 2u: 5.59E-01 ir: 3.30E-07 iu: 1.50E-01 rsn: itol_upd
#
#  Step      5 Time=  1.80000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       6] linear =     1 [         6] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   3.718102E-07  5.809534E-09  3.298495E-07
#   --> max chng: dpmx=   1.4951E-01 dtmpmx=   4.9330E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.08E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.00E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 3.88E-07 2x: 1.23E+06 2u: 6.64E-01 ir: 3.55E-07 iu: 1.70E-01 rsn: itol_upd
#
#  Step      6 Time=  2.16000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       7] linear =     1 [         7] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   3.881575E-07  6.064961E-09  3.548930E-07
#   --> max chng: dpmx=   1.6974E-01 dtmpmx=   4.4652E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 9.33E-04 2x: 0.00E+00 2u: 0.00E+00 ir: 6.61E-04 iu: 0.00E+00 rsn:   0
#   1 2r: 1.14E-06 2x: 1.23E+06 2u: 8.14E-01 ir: 1.08E-06 iu: 1.89E-01 rsn: itol_upd
#
#  Step      7 Time=  2.52000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       8] linear =     1 [         8] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.140195E-06  1.781554E-08  1.078558E-06
#   --> max chng: dpmx=   1.8910E-01 dtmpmx=   3.9306E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 4.86E-04 2x: 0.00E+00 2u: 0.00E+00 ir: 3.98E-04 iu: 0.00E+00 rsn:   0
#   1 2r: 5.88E-07 2x: 1.23E+06 2u: 8.13E-01 ir: 5.57E-07 iu: 1.75E-01 rsn: itol_upd
#
#  Step      8 Time=  2.88000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       9] linear =     1 [         9] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   5.882459E-07  9.191342E-09  5.571478E-07
#   --> max chng: dpmx=   1.7452E-01 dtmpmx=   3.4974E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 8.62E-04 2x: 0.00E+00 2u: 0.00E+00 ir: 5.92E-04 iu: 0.00E+00 rsn:   0
#   1 2r: 1.13E-06 2x: 1.23E+06 2u: 8.59E-01 ir: 1.07E-06 iu: 1.61E-01 rsn: itol_upd
#
#  Step      9 Time=  3.24000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      10] linear =     1 [        10] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.126555E-06  1.760242E-08  1.066713E-06
#   --> max chng: dpmx=   1.6110E-01 dtmpmx=   3.1420E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.45E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.31E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.14E-06 2x: 1.23E+06 2u: 8.13E-01 ir: 1.07E-06 iu: 1.41E-01 rsn: itol_upd
#
#  Step     10 Time=  3.60000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      11] linear =     1 [        11] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.139677E-06  1.780746E-08  1.069226E-06
#   --> max chng: dpmx=   1.4137E-01 dtmpmx=   5.4281E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 2.27E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 2.16E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.56E-06 2x: 1.23E+06 2u: 7.57E-01 ir: 1.42E-06 iu: 1.25E-01 rsn: itol_upd
#
#  Step     11 Time=  3.96000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      12] linear =     1 [        12] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.559696E-06  2.437024E-08  1.417443E-06
#   --> max chng: dpmx=   1.2505E-01 dtmpmx=   9.0601E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 2.51E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 2.40E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.65E-06 2x: 1.23E+06 2u: 6.72E-01 ir: 1.47E-06 iu: 1.06E-01 rsn: itol_upd
#
#  Step     12 Time=  4.32000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      13] linear =     1 [        13] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.650138E-06  2.578340E-08  1.471523E-06
#   --> max chng: dpmx=   1.0598E-01 dtmpmx=   1.0230E-01
#
#  --> appending to hdf5 output file: R3.h5
#        0.00 Seconds to write HDF5 file.
#   --> Dump checkpoint file: R3-restart.chk
#        Seconds to write to checkpoint file:       0.00
#
# FLOW TS BE steps =     12 newton =       13 linear =         13 cuts =      0
# FLOW TS BE Wasted Linear Iterations = 0
# FLOW TS BE SNES time = 0.0 seconds
#
#  Wall Clock Time:  5.6167E-02 [sec]   9.3611E-04 [min]   1.5602E-05 [hr]
#  "grid_structured_type" set to default value.
#  Opening hdf5 file: ../pflotran_input/parameter.h5
#  pflotran card:: TIMESTEPPER
#  pflotran card:: TIMESTEPPER
#  pflotran card:: NEWTON_SOLVER
#  pflotran card:: LINEAR_SOLVER
#  pflotran card:: NEWTON_SOLVER
#  pflotran card:: LINEAR_SOLVER
#  pflotran card:: GRID
#  pflotran card:: FLUID_PROPERTY
#  "FLUID_PROPERTY,diffusion_coeffient units" set to default value.
#  pflotran card:: MATERIAL_PROPERTY
#    Name :: Alluvium
#  "MATERIAL_PROPERTY,rock density units" set to default value.
#  "MATERIAL_PROPERTY,specific heat units" set to default value.
#  "MATERIAL_PROPERTY,dry thermal conductivity units" set to default value.
#  "MATERIAL_PROPERTY,wet thermal conductivity units" set to default value.
#  pflotran card:: CHARACTERISTIC_CURVES
#    Name :: default
#  WARNING: A default Saturation Function has been chosen in CHARACTERISTIC_CURVES(default),.
#  WARNING: A default Relative Permeability Function has been chosen in CHARACTERISTIC_CURVES(default),.
#  WARNING: A default Relative Permeability Function has been chosen in CHARACTERISTIC_CURVES(default),.
#  pflotran card:: OUTPUT
#  pflotran card:: TIME
#  pflotran card:: REGION
#  all
#  pflotran card:: REGION
#  top
#  pflotran card:: REGION
#  bottom
#  pflotran card:: DBASE_FILENAME
#  pflotran card:: MINIMUM_HYDROSTATIC_PRESSURE
#  "Minimum Hydrostatic Pressure units" set to default value.
#  pflotran card:: FLOW_CONDITION
#  initial
#  WARNING: "iphase" not set in condition; set to 1
#  pflotran card:: FLOW_CONDITION
#  flow_top
#  WARNING: "iphase" not set in condition; set to 1
#  pflotran card:: FLOW_CONDITION
#  flow_bottom
#  WARNING: "iphase" not set in condition; set to 1
#  pflotran card:: INITIAL_CONDITION
#  pflotran card:: BOUNDARY_CONDITION
#  pflotran card:: BOUNDARY_CONDITION
#  pflotran card:: STRATA
#  pflotran card:: END_SUBSURFACE
#  Domain Bounds (x y z):
#      0.0000000000E+00  0.0000000000E+00 -6.4000000000E-01
#      1.0000000000E+00  1.0000000000E+00  0.0000000000E+00
#  Extent of Gridded Domain
#   X: 0.0000000000000000 - 1.0000000000000000
#   Y: 0.0000000000000000 - 1.0000000000000000
#   Z: -0.64000000000000001 - 0.0000000000000000
#
#  Default HDF5 method is used in Initialization
#
#  Requested processors and decomposition =     1, npx,y,z=   -1  -1  -1
#  Actual decomposition: npx,y,z=    1   1   1
#
#    Beginning setup of FLOW SNES
#  number of dofs =   2, number of phases =   1
#  mode = TH: p, T
#    Finished setting up FLOW SNES
#
# FLOW Time Stepper
#                  acceleration: on
#        acceleration threshold: 8
#        number of ramp entries: 8
#                 ramp entry #1: 2.0000
#                 ramp entry #2: 2.0000
#                 ramp entry #3: 2.0000
#                 ramp entry #4: 2.0000
#                 ramp entry #5: 2.0000
#                 ramp entry #6: 1.8000
#                 ramp entry #7: 1.6000
#                 ramp entry #8: 1.4000
#                 ramp entry #9: 1.2000
#                ramp entry #10: 1.0000
#                ramp entry #11: 1.0000
#                ramp entry #12: 1.0000
#                ramp entry #13: 1.0000
#       maximum number of steps: 999999
# constant time steps threshold: 5
#        maximum number of cuts: 50
#              reduction factor: 5.000000E-01
#         maximum growth factor: 2.000000E+00
#
# FLOW Newton Solver
#                          atol: 1.000000E-50
#                          rtol: 1.000000E-50
#                          stol: 1.000000E-60
#                          dtol: 1.000000E+20
#                       maxnorm: 1.000000E+20
#                     inftolres: -9.990000E+02
#                     inftolupd: 1.000000E+00
#                  inftolrelupd: -9.990000E+02
#                  inftolsclres: -9.990000E+02
#                      max iter: 20
#                      min iter: 1
#                          maxf: 10000
#                   matrix type: baij
#          precond. matrix type: baij
#                inexact newton: off
#             print convergence: on
#    print detailed convergence: off
#           check infinity norm: on
#
# FLOW Linear Solver
#                        solver: bcgs
#                preconditioner: ilu
#                          atol: 1.000000E-50
#                          rtol: 1.000000E-05
#                          dtol: 1.000000E+04
#             maximum iteration: 10000
#  --> creating hdf5 output file: R4.h5
#        0.00 Seconds to write HDF5 file.
#
#    Finished Initialization
#
# == TH FLOW =====================================================================
#   0 2r: 1.53E+03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.41E+03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.31E-04 2x: 1.23E+06 2u: 3.92E+05 ir: 9.00E-05 iu: 4.91E+04 rsn:   0
#   2 2r: 6.99E-09 2x: 1.23E+06 2u: 7.05E-02 ir: 4.95E-09 iu: 1.91E-02 rsn: itol_upd
#
#  Step      1 Time=  3.60000E+03 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   2 [       2] linear =     2 [         2] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            2  /            2
#   --> SNES Residual:   6.988232E-09  1.091911E-10  4.949477E-09
#   --> max chng: dpmx=   4.9065E+04 dtmpmx=   1.5172E-01
#
#
# == TH FLOW =====================================================================
#   0 2r: 9.37E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 6.88E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.06E-04 2x: 1.23E+06 2u: 1.50E+00 ir: 1.01E-04 iu: 2.13E-01 rsn: itol_upd
#
#  Step      2 Time=  7.20000E+03 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       3] linear =     1 [         3] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.061988E-04  1.659356E-06  1.006457E-04
#   --> max chng: dpmx=   1.9113E-01 dtmpmx=   2.1329E-01
#
#
# == TH FLOW =====================================================================
#   0 2r: 2.30E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 2.28E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 7.24E-08 2x: 1.23E+06 2u: 1.26E-01 ir: 4.79E-08 iu: 5.43E-02 rsn: itol_upd
#
#  Step      3 Time=  1.08000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       4] linear =     1 [         4] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   7.237123E-08  1.130800E-09  4.793602E-08
#   --> max chng: dpmx=   3.1895E-03 dtmpmx=   5.4344E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 2.12E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 2.12E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 5.01E-08 2x: 1.23E+06 2u: 1.32E-01 ir: 4.35E-08 iu: 5.37E-02 rsn: itol_upd
#
#  Step      4 Time=  1.44000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       5] linear =     1 [         5] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   5.008145E-08  7.825227E-10  4.348944E-08
#   --> max chng: dpmx=   8.0426E-03 dtmpmx=   5.3692E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.93E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.86E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 3.94E-07 2x: 1.23E+06 2u: 1.69E-01 ir: 3.71E-07 iu: 4.81E-02 rsn: itol_upd
#
#  Step      5 Time=  1.80000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       6] linear =     1 [         6] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   3.935549E-07  6.149296E-09  3.712332E-07
#   --> max chng: dpmx=   1.9170E-02 dtmpmx=   4.8138E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.71E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.63E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 4.09E-07 2x: 1.23E+06 2u: 1.72E-01 ir: 3.86E-07 iu: 4.26E-02 rsn: itol_upd
#
#  Step      6 Time=  2.16000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       7] linear =     1 [         7] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   4.086228E-07  6.384732E-09  3.864170E-07
#   --> max chng: dpmx=   2.0038E-02 dtmpmx=   4.2566E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.40E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.07E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.27E-06 2x: 1.23E+06 2u: 2.23E-01 ir: 1.20E-06 iu: 3.08E-02 rsn: itol_upd
#
#  Step      7 Time=  2.52000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       8] linear =     1 [         8] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.265206E-06  1.976884E-08  1.200056E-06
#   --> max chng: dpmx=   2.9415E-02 dtmpmx=   3.0774E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 6.61E-04 2x: 0.00E+00 2u: 0.00E+00 ir: 4.82E-04 iu: 0.00E+00 rsn:   0
#   1 2r: 6.18E-07 2x: 1.23E+06 2u: 1.65E-01 ir: 5.86E-07 iu: 2.18E-02 rsn: itol_upd
#
#  Step      8 Time=  2.88000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       9] linear =     1 [         9] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   6.179784E-07  9.655912E-09  5.863015E-07
#   --> max chng: dpmx=   2.1623E-02 dtmpmx=   2.1796E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.33E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 9.85E-04 iu: 0.00E+00 rsn:   0
#   1 2r: 1.20E-06 2x: 1.23E+06 2u: 2.00E-01 ir: 1.14E-06 iu: 2.58E-02 rsn: itol_upd
#
#  Step      9 Time=  3.24000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      10] linear =     1 [        10] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.201453E-06  1.877271E-08  1.139690E-06
#   --> max chng: dpmx=   2.5836E-02 dtmpmx=   2.3364E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 2.33E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 2.16E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.18E-06 2x: 1.23E+06 2u: 2.09E-01 ir: 1.12E-06 iu: 5.27E-02 rsn: itol_upd
#
#  Step     10 Time=  3.60000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      11] linear =     1 [        11] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.177283E-06  1.839505E-08  1.115938E-06
#   --> max chng: dpmx=   2.4342E-02 dtmpmx=   5.2700E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 3.69E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 3.54E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.56E-06 2x: 1.23E+06 2u: 2.66E-01 ir: 1.48E-06 iu: 8.82E-02 rsn: itol_upd
#
#  Step     11 Time=  3.96000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      12] linear =     1 [        12] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.564825E-06  2.445040E-08  1.479026E-06
#   --> max chng: dpmx=   2.6472E-02 dtmpmx=   8.8203E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 4.06E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 3.92E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.61E-06 2x: 1.23E+06 2u: 2.96E-01 ir: 1.52E-06 iu: 9.94E-02 rsn: itol_upd
#
#  Step     12 Time=  4.32000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      13] linear =     1 [        13] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.611014E-06  2.517209E-08  1.519645E-06
#   --> max chng: dpmx=   2.6054E-02 dtmpmx=   9.9395E-02
#
#  --> appending to hdf5 output file: R4.h5
#        0.00 Seconds to write HDF5 file.
#   --> Dump checkpoint file: R4-restart.chk
#        Seconds to write to checkpoint file:       0.00
#
# FLOW TS BE steps =     12 newton =       13 linear =         13 cuts =      0
# FLOW TS BE Wasted Linear Iterations = 0
# FLOW TS BE SNES time = 0.0 seconds
#
#  Wall Clock Time:  5.6672E-02 [sec]   9.4453E-04 [min]   1.5742E-05 [hr]
#  "grid_structured_type" set to default value.
#  Opening hdf5 file: ../pflotran_input/parameter.h5
#  pflotran card:: TIMESTEPPER
#  pflotran card:: TIMESTEPPER
#  pflotran card:: NEWTON_SOLVER
#  pflotran card:: LINEAR_SOLVER
#  pflotran card:: NEWTON_SOLVER
#  pflotran card:: LINEAR_SOLVER
#  pflotran card:: GRID
# ...
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   3.738215E-07  5.840961E-09  3.489406E-07
#   --> max chng: dpmx=   6.2640E-02 dtmpmx=   4.3512E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 8.40E-04 2x: 0.00E+00 2u: 0.00E+00 ir: 5.93E-04 iu: 0.00E+00 rsn:   0
#   1 2r: 1.14E-06 2x: 1.23E+06 2u: 3.52E-01 ir: 1.08E-06 iu: 7.52E-02 rsn: itol_upd
#
#  Step      7 Time=  2.52000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       8] linear =     1 [         8] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.140861E-06  1.782595E-08  1.080568E-06
#   --> max chng: dpmx=   7.5165E-02 dtmpmx=   3.6356E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 4.53E-04 2x: 0.00E+00 2u: 0.00E+00 ir: 3.98E-04 iu: 0.00E+00 rsn:   0
#   1 2r: 5.73E-07 2x: 1.23E+06 2u: 3.14E-01 ir: 5.43E-07 iu: 6.55E-02 rsn: itol_upd
#
#  Step      8 Time=  2.88000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       9] linear =     1 [         9] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   5.725082E-07  8.945440E-09  5.425158E-07
#   --> max chng: dpmx=   6.5531E-02 dtmpmx=   3.0728E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 7.73E-04 2x: 0.00E+00 2u: 0.00E+00 ir: 5.56E-04 iu: 0.00E+00 rsn:   0
#   1 2r: 1.10E-06 2x: 1.23E+06 2u: 3.55E-01 ir: 1.04E-06 iu: 6.53E-02 rsn: itol_upd
#
#  Step      9 Time=  3.24000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      10] linear =     1 [        10] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.096682E-06  1.713565E-08  1.039082E-06
#   --> max chng: dpmx=   6.5313E-02 dtmpmx=   2.6258E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.23E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.09E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.09E-06 2x: 1.23E+06 2u: 3.53E-01 ir: 1.03E-06 iu: 5.97E-02 rsn: itol_upd
#
#  Step     10 Time=  3.60000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      11] linear =     1 [        11] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.087940E-06  1.699906E-08  1.027069E-06
#   --> max chng: dpmx=   5.9651E-02 dtmpmx=   5.2483E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.91E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.80E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.46E-06 2x: 1.23E+06 2u: 3.86E-01 ir: 1.36E-06 iu: 8.83E-02 rsn: itol_upd
#
#  Step     11 Time=  3.96000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      12] linear =     1 [        12] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.459606E-06  2.280634E-08  1.359846E-06
#   --> max chng: dpmx=   5.7986E-02 dtmpmx=   8.8350E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 2.11E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 2.00E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.52E-06 2x: 1.23E+06 2u: 3.98E-01 ir: 1.41E-06 iu: 1.00E-01 rsn: itol_upd
#
#  Step     12 Time=  4.32000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      13] linear =     1 [        13] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.522958E-06  2.379622E-08  1.406035E-06
#   --> max chng: dpmx=   5.4047E-02 dtmpmx=   1.0048E-01
#
#  --> appending to hdf5 output file: R29.h5
#        0.00 Seconds to write HDF5 file.
#   --> Dump checkpoint file: R29-restart.chk
#        Seconds to write to checkpoint file:       0.00
#
# FLOW TS BE steps =     12 newton =       13 linear =         13 cuts =      0
# FLOW TS BE Wasted Linear Iterations = 0
# FLOW TS BE SNES time = 0.0 seconds
#
#  Wall Clock Time:  5.7859E-02 [sec]   9.6432E-04 [min]   1.6072E-05 [hr]
#  "grid_structured_type" set to default value.
#  Opening hdf5 file: ../pflotran_input/parameter.h5
#  pflotran card:: TIMESTEPPER
#  pflotran card:: TIMESTEPPER
#  pflotran card:: NEWTON_SOLVER
#  pflotran card:: LINEAR_SOLVER
#  pflotran card:: NEWTON_SOLVER
#  pflotran card:: LINEAR_SOLVER
#  pflotran card:: GRID
#  pflotran card:: FLUID_PROPERTY
#  "FLUID_PROPERTY,diffusion_coeffient units" set to default value.
#  pflotran card:: MATERIAL_PROPERTY
#    Name :: Alluvium
#  "MATERIAL_PROPERTY,rock density units" set to default value.
#  "MATERIAL_PROPERTY,specific heat units" set to default value.
#  "MATERIAL_PROPERTY,dry thermal conductivity units" set to default value.
#  "MATERIAL_PROPERTY,wet thermal conductivity units" set to default value.
#  pflotran card:: CHARACTERISTIC_CURVES
#    Name :: default
#  WARNING: A default Saturation Function has been chosen in CHARACTERISTIC_CURVES(default),.
#  WARNING: A default Relative Permeability Function has been chosen in CHARACTERISTIC_CURVES(default),.
#  WARNING: A default Relative Permeability Function has been chosen in CHARACTERISTIC_CURVES(default),.
#  pflotran card:: OUTPUT
#  pflotran card:: TIME
#  pflotran card:: REGION
#  all
#  pflotran card:: REGION
#  top
#  pflotran card:: REGION
#  bottom
#  pflotran card:: DBASE_FILENAME
#  pflotran card:: MINIMUM_HYDROSTATIC_PRESSURE
#  "Minimum Hydrostatic Pressure units" set to default value.
#  pflotran card:: FLOW_CONDITION
#  initial
#  WARNING: "iphase" not set in condition; set to 1
#  pflotran card:: FLOW_CONDITION
#  flow_top
#  WARNING: "iphase" not set in condition; set to 1
#  pflotran card:: FLOW_CONDITION
#  flow_bottom
#  WARNING: "iphase" not set in condition; set to 1
#  pflotran card:: INITIAL_CONDITION
#  pflotran card:: BOUNDARY_CONDITION
#  pflotran card:: BOUNDARY_CONDITION
#  pflotran card:: STRATA
#  pflotran card:: END_SUBSURFACE
#  Domain Bounds (x y z):
#      0.0000000000E+00  0.0000000000E+00 -6.4000000000E-01
#      1.0000000000E+00  1.0000000000E+00  0.0000000000E+00
#  Extent of Gridded Domain
#   X: 0.0000000000000000 - 1.0000000000000000
#   Y: 0.0000000000000000 - 1.0000000000000000
#   Z: -0.64000000000000001 - 0.0000000000000000
#
#  Default HDF5 method is used in Initialization
#
#  Requested processors and decomposition =     1, npx,y,z=   -1  -1  -1
#  Actual decomposition: npx,y,z=    1   1   1
#
#    Beginning setup of FLOW SNES
#  number of dofs =   2, number of phases =   1
#  mode = TH: p, T
#    Finished setting up FLOW SNES
#
# FLOW Time Stepper
#                  acceleration: on
#        acceleration threshold: 8
#        number of ramp entries: 8
#                 ramp entry #1: 2.0000
#                 ramp entry #2: 2.0000
#                 ramp entry #3: 2.0000
#                 ramp entry #4: 2.0000
#                 ramp entry #5: 2.0000
#                 ramp entry #6: 1.8000
#                 ramp entry #7: 1.6000
#                 ramp entry #8: 1.4000
#                 ramp entry #9: 1.2000
#                ramp entry #10: 1.0000
#                ramp entry #11: 1.0000
#                ramp entry #12: 1.0000
#                ramp entry #13: 1.0000
#       maximum number of steps: 999999
# constant time steps threshold: 5
#        maximum number of cuts: 50
#              reduction factor: 5.000000E-01
#         maximum growth factor: 2.000000E+00
#
# FLOW Newton Solver
#                          atol: 1.000000E-50
#                          rtol: 1.000000E-50
#                          stol: 1.000000E-60
#                          dtol: 1.000000E+20
#                       maxnorm: 1.000000E+20
#                     inftolres: -9.990000E+02
#                     inftolupd: 1.000000E+00
#                  inftolrelupd: -9.990000E+02
#                  inftolsclres: -9.990000E+02
#                      max iter: 20
#                      min iter: 1
#                          maxf: 10000
#                   matrix type: baij
#          precond. matrix type: baij
#                inexact newton: off
#             print convergence: on
#    print detailed convergence: off
#           check infinity norm: on
#
# FLOW Linear Solver
#                        solver: bcgs
#                preconditioner: ilu
#                          atol: 1.000000E-50
#                          rtol: 1.000000E-05
#                          dtol: 1.000000E+04
#             maximum iteration: 10000
#  --> creating hdf5 output file: R30.h5
#        0.00 Seconds to write HDF5 file.
#
#    Finished Initialization
#
# == TH FLOW =====================================================================
#   0 2r: 1.53E+03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.41E+03 iu: 0.00E+00 rsn:   0
#   1 2r: 3.36E-04 2x: 1.23E+06 2u: 3.92E+05 ir: 2.42E-04 iu: 4.90E+04 rsn:   0
#   2 2r: 6.72E-08 2x: 1.23E+06 2u: 2.73E-01 ir: 4.62E-08 iu: 5.13E-02 rsn: itol_upd
#
#  Step      1 Time=  3.60000E+03 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   2 [       2] linear =     2 [         2] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            2  /            2
#   --> SNES Residual:   6.716582E-08  1.049466E-09  4.621111E-08
#   --> max chng: dpmx=   4.9035E+04 dtmpmx=   1.5322E-01
#
#
# == TH FLOW =====================================================================
#   0 2r: 7.86E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 5.26E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 2.38E-07 2x: 1.23E+06 2u: 1.22E+00 ir: 1.70E-07 iu: 2.20E-01 rsn: itol_upd
#
#  Step      2 Time=  7.20000E+03 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       3] linear =     1 [         3] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   2.376011E-07  3.712517E-09  1.702053E-07
#   --> max chng: dpmx=   1.8082E-01 dtmpmx=   2.2033E-01
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.77E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.75E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 9.74E-09 2x: 1.23E+06 2u: 1.69E-01 ir: 6.89E-09 iu: 5.21E-02 rsn: itol_upd
#
#  Step      3 Time=  1.08000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       4] linear =     1 [         4] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   9.735015E-09  1.521096E-10  6.892984E-09
#   --> max chng: dpmx=   1.5936E-02 dtmpmx=   5.2122E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.64E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.64E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 3.82E-09 2x: 1.23E+06 2u: 1.45E-01 ir: 3.20E-09 iu: 5.17E-02 rsn: itol_upd
#
#  Step      4 Time=  1.44000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       5] linear =     1 [         5] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   3.820600E-09  5.969688E-11  3.198535E-09
#   --> max chng: dpmx=   1.3848E-02 dtmpmx=   5.1690E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.51E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.44E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 2.00E-09 2x: 1.23E+06 2u: 1.60E-01 ir: 1.55E-09 iu: 4.63E-02 rsn: itol_upd
#
#  Step      5 Time=  1.80000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       6] linear =     1 [         6] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.999470E-09  3.124171E-11  1.547031E-09
#   --> max chng: dpmx=   1.7943E-02 dtmpmx=   4.6347E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.33E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.26E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.13E-09 2x: 1.23E+06 2u: 1.36E-01 ir: 7.94E-10 iu: 4.10E-02 rsn: itol_upd
#
#  Step      6 Time=  2.16000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       7] linear =     1 [         7] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.128088E-09  1.762638E-11  7.941588E-10
#   --> max chng: dpmx=   1.4602E-02 dtmpmx=   4.0960E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.14E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 8.25E-04 iu: 0.00E+00 rsn:   0
#   1 2r: 1.59E-09 2x: 1.23E+06 2u: 1.56E-01 ir: 1.24E-09 iu: 2.77E-02 rsn: itol_upd
#
#  Step      7 Time=  2.52000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       8] linear =     1 [         8] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.586743E-09  2.479286E-11  1.236879E-09
#   --> max chng: dpmx=   1.9936E-02 dtmpmx=   2.7730E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 5.61E-04 2x: 0.00E+00 2u: 0.00E+00 ir: 3.88E-04 iu: 0.00E+00 rsn:   0
#   1 2r: 6.44E-10 2x: 1.23E+06 2u: 9.13E-02 ir: 3.78E-10 iu: 1.72E-02 rsn: itol_upd
#
#  Step      8 Time=  2.88000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [       9] linear =     1 [         9] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   6.441408E-10  1.006470E-11  3.783355E-10
#   --> max chng: dpmx=   1.3369E-02 dtmpmx=   1.7237E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.07E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 7.60E-04 iu: 0.00E+00 rsn:   0
#   1 2r: 2.22E-09 2x: 1.23E+06 2u: 1.12E-01 ir: 1.49E-09 iu: 2.39E-02 rsn: itol_upd
#
#  Step      9 Time=  3.24000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      10] linear =     1 [        10] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   2.224518E-09  3.475810E-11  1.487757E-09
#   --> max chng: dpmx=   1.8695E-02 dtmpmx=   2.3912E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 1.83E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 1.67E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 6.11E-09 2x: 1.23E+06 2u: 1.26E-01 ir: 5.00E-09 iu: 5.09E-02 rsn: itol_upd
#
#  Step     10 Time=  3.60000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      11] linear =     1 [        11] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   6.110468E-09  9.547606E-11  5.001519E-09
#   --> max chng: dpmx=   1.8048E-02 dtmpmx=   5.0868E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 2.87E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 2.74E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.36E-08 2x: 1.23E+06 2u: 1.81E-01 ir: 1.13E-08 iu: 8.51E-02 rsn: itol_upd
#
#  Step     11 Time=  3.96000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      12] linear =     1 [        12] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.359004E-08  2.123444E-10  1.132931E-08
#   --> max chng: dpmx=   2.0481E-02 dtmpmx=   8.5063E-02
#
#
# == TH FLOW =====================================================================
#   0 2r: 3.16E-03 2x: 0.00E+00 2u: 0.00E+00 ir: 3.03E-03 iu: 0.00E+00 rsn:   0
#   1 2r: 1.28E-08 2x: 1.23E+06 2u: 2.08E-01 ir: 1.08E-08 iu: 9.59E-02 rsn: itol_upd
#
#  Step     12 Time=  4.32000E+04 Dt=  3.60000E+03 [sec] snes_conv_reason:   11
#   newton =   1 [      13] linear =     1 [        13] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations =            1  /            1
#   --> SNES Residual:   1.279568E-08  1.999325E-10  1.079224E-08
#   --> max chng: dpmx=   2.0943E-02 dtmpmx=   9.5867E-02
#
#  --> appending to hdf5 output file: R30.h5
#        0.00 Seconds to write HDF5 file.
#   --> Dump checkpoint file: R30-restart.chk
#        Seconds to write to checkpoint file:       0.00
#
# FLOW TS BE steps =     12 newton =       13 linear =         13 cuts =      0
# FLOW TS BE Wasted Linear Iterations = 0
# FLOW TS BE SNES time = 0.0 seconds
#
#  Wall Clock Time:  5.9248E-02 [sec]   9.8747E-04 [min]   1.6458E-05 [hr]
# Finished running PFLOTRAN...

# %% [markdown]
# # DART files preparation
# In this section, the following procedures are conducted for DART:
# - generate the template for DART generic variable quantity files (i.e., ```DEFAULT_obs_kind_mod.F90``` and ```obs_def_pflotran_mod.f90```);
# - run ```preprocess``` to generate the rest of DART generic variable quantity files;
# - convert the observation file to DART observation format;
# - generate ```prior.nc``` at the first time step;
# - generate ```input.nml```;
# - conduct ```check_model_mod```.

# %% [markdown]
# ## Generate the templates for DART generic variable quantity files
# - Run: ```list2dartqty.py``` to sequentially generate
#     - a mapping between PFLOTRAN variales and DART generic quantities in ```obs_def_pflotran_mod.F90```
#     - the default DART generic quantity definition file ```DEFAULT_obs_kind_mod.F90```
# - Code input arguments:
#     - filename for ```DEFAULT_obs_kind_mod.F90```
#     - filename for ```obs_def_pflotran_mod.F90```
#     - a list of variables required to be assimilated

# %%
# %%script bash -s "$to_dartqty" "$obs_type" "$def_obs_kind" "$pflotran_parastate_set"
# python $1 $2 $3 $4
# Out:
# The added DART variable quantities names and indices are ...
# []
# []
# Finished generating the ../obs_kind/DEFAULT_obs_kind_mod.f90...
# Finished generating the ../obs_type/obs_def_pflotran_mod.f90...

# %% [markdown]
# ## Generate ```prior.nc``` from the model spin-up
# - The structure of ```prior_R[ENS].nc``` file (```[ENS]``` refers to the ensemble number):
#
# | NetCDF dimensions |                      NetCDF variables                      |
# |:-----------------:|:----------------------------------------------------------:|
# | time: 1           | time: shape(time)                                          |
# | x_location: nx    | x_location: shape(x_location)                              |
# | y_location: ny    | y_location: shape(y_location)                              |
# | z_location: nz    | z_location: shape(z_location)                              |
# | member: 1         | member: shape(member)                                      |
# |                   | physical variable: shape(x_location,y_location,z_location) |
#
# **Note that** required by DART, each ```prior_R[ENS].nc``` file only includes the state/parameter values of one ensemble member at one given time. For the time, PFLOTRAN generates the time step with the initial time as 0. Also, it is different from the definition for the [observation NetCDF](#observationconvertion), because ```prior_R[ENS].nc``` aims for the structured cartesian grids while the observation NetCDF aims for a general case.
#
# - Run: ```prepare_prior_nc.py``` to generate
#     - the prior input file ```prior_R[ENS].nc``` for DART
#     - the prior template file (copied from ```prior_R1.nc```) for ```input.nml```
# - Code input arguments:
#     - filename ```R[ENS].h5``` from PFLOTRAN model output
#     - pflotran parameter HDF file ```parameter.h5```
#     - filename ```prior_R[ENS].nc``` for the prior input file for DART
#     - number of ensemble
#     - a list of variables to be assimilated

# %%
# %%script bash -s "$prep_prior_nc" "$pflotran_out" "$pflotran_para" "$dart_prior_nc" "$nens" "$pflotran_parastate_set"
# python $1 $2 $3 $4 $5 $6
# Out:
# Converting state/parameter into NetCDF file for ensemble 1...
# Converting state/parameter into NetCDF file for ensemble 2...
# Converting state/parameter into NetCDF file for ensemble 3...
# Converting state/parameter into NetCDF file for ensemble 4...
# Converting state/parameter into NetCDF file for ensemble 5...
# Converting state/parameter into NetCDF file for ensemble 6...
# Converting state/parameter into NetCDF file for ensemble 7...
# Converting state/parameter into NetCDF file for ensemble 8...
# Converting state/parameter into NetCDF file for ensemble 9...
# Converting state/parameter into NetCDF file for ensemble 10...
# Converting state/parameter into NetCDF file for ensemble 11...
# Converting state/parameter into NetCDF file for ensemble 12...
# Converting state/parameter into NetCDF file for ensemble 13...
# Converting state/parameter into NetCDF file for ensemble 14...
# Converting state/parameter into NetCDF file for ensemble 15...
# Converting state/parameter into NetCDF file for ensemble 16...
# Converting state/parameter into NetCDF file for ensemble 17...
# Converting state/parameter into NetCDF file for ensemble 18...
# Converting state/parameter into NetCDF file for ensemble 19...
# Converting state/parameter into NetCDF file for ensemble 20...
# Converting state/parameter into NetCDF file for ensemble 21...
# Converting state/parameter into NetCDF file for ensemble 22...
# Converting state/parameter into NetCDF file for ensemble 23...
# Converting state/parameter into NetCDF file for ensemble 24...
# Converting state/parameter into NetCDF file for ensemble 25...
# Converting state/parameter into NetCDF file for ensemble 26...
# Converting state/parameter into NetCDF file for ensemble 27...
# Converting state/parameter into NetCDF file for ensemble 28...
# Converting state/parameter into NetCDF file for ensemble 29...
# Converting state/parameter into NetCDF file for ensemble 30...

# %% [markdown]
# ## Generate ```input.nml```
# Provide parameters for different namelists in input.nml
# - [filter_nml](https://www.image.ucar.edu/DAReS/DART/Manhattan/assimilation_code/modules/observations/obs_sequence_mod.html): namelist of the main module for driving ensemble filter assimilations
# - [obs_kind_nml](https://www.image.ucar.edu/DAReS/DART/Manhattan/assimilation_code/modules/observations/obs_kind_mod.html#Namelist): namelist for controling what observation types are to be assimilated
# - [preprocess_nml](file:///Users/jian449/Codes/DART/manhattan/assimilation_code/programs/preprocess/preprocess): namelist of the DART-supplied preprocessor program which creates observation kind and observation definition modules from a set of other specially formatted Fortran 90 files
# - model_nml: a self-defined namelist for providing the basic information in the model

# %% [markdown]
# ***************
# Assemble all the namelists in input.nml

# %%
# Parameters for different namelists in input.nml
filter_nml = {"input_state_file_list":"filter_input_list.txt",
              "output_state_file_list":"filter_output_list.txt",
              "ens_size":nens,
              "async":2,
              "adv_ens_command":advance_model,
              "obs_sequence_in_name":obs_dart}
obs_kind_nml = {"assimilate_these_obs_types":obs_var_set}
model_nml = {"time_step_days":0,
             "time_step_seconds":0,
             "nvar":len(pflotran_parastate_set),
             "var_names":pflotran_parastate_set,
             "template_file":re.sub(r"\[ENS\]",'template',dart_prior_nc),
             "var_qtynames":['QTY_PFLOTRAN_'+v for v in pflotran_parastate_set]}
preprocess_nml = {"input_files":obs_type,
                  "input_obs_kind_mod_file":def_obs_kind}
convertnc_nml = {"netcdf_file": obs_nc,
                 "out_file": obs_dart}
inputnml = {"filter_nml":filter_nml,
            "obs_kind_nml":obs_kind_nml,
            "model_nml":model_nml,
            "preprocess_nml":preprocess_nml,
            "convertnc_nml":convertnc_nml}

# Save it in a temperory pickle file
with open(input_nml_dict, 'wb') as f:
    pickle.dump(inputnml, f)

# %% [markdown]
# ***************
# - Run: ```prepare_inputnml.py```
# - Code input arguments:
#     - input_nml: the ```input.nml``` namelist file
#     - input_nml_dict: the ```inputnml.p``` pickle file

# %%
# %%script bash -s  "$prep_inputnml" "$input_nml" "$input_nml_dict"
# python $1 $2 $3
# Out:
# Finished generating the input namelist file...

# %% [markdown]
# <a id='observationconvertion'></a>
# ## Convert observation to DART observation format
# In this section, the observation data is converted in DART format. We first convert observation data in raw format into NetCDF format. Then, the observation file is converted into DART format. The structure of NetCDF file for recording observation file.
#
# | NetCDF dimensions |           NetCDF variables          |
# |:-----------------:|:-----------------------------------:|
# | time: 1           | time: shape(time)                   |
# | location: nloc    | location: shape(location)           |
# |                   | physical variable: shape(time,nloc) |
#
# **Note that** if the time calendar follows *gregorian*, the time unit should be entered as ```seconds since YYYY-MM-DD HH:MM:SS```. Otherwise, put the time calender as *None* and time unit as ```second``` (make sure convert your measurement times to seconds).

# %% [markdown]
# ***************
# - Run: ```csv2nc.py``` to convert the raw csv temperature observations to NetCDF file
# - Code input arguments:
#     - filename for the original observed temperature file
#     - filename for the observation NetCDF file

# %%
# %%script bash -s "$csv_to_nc" "$obs_original" "$obs_nc"
# python $1 $2 $3
# Out:
# Finished converting raw observation in NetCDF format...

# %% [markdown]
# ***************
# - Run: ```prepare_convert_nc.py``` to prepare the ```convert_nc.f90``` based on the list of observation variables.
# - Code input arguments:
#     - filename for the observation NetCDF file

# %%
# %%script bash -s "$prep_convert_nc" "$obs_nc"
# python $1 $2

# %% [markdown]
# ***************
# - Run: ```prepare_convertnc_nml.py``` to prepare the namelist containing the location and file names required for convert_nc.f90.
# - Code input arguments:
#     - filename for the observation NetCDF file
#     - filename for the observation file in DART format

# %%
# %%script bash -s "$prep_convertncnml" "$obs_nc" "$obs_dart"
# python $1 $2 $3

# %% [markdown]
# ***************
# - Run shell script: ```dart_seq_convert.csh``` to
#     - preprocess the DART generic variable quantity files prepared by the previous section
#     - generate an executable file for converting observation file in NetCDF format to DART format used by the next section

# %%
# %%script bash -s "$work_dir" "$compile_convert_nc"
# cd $1
# csh $2
# Out:
# ---------------------------------------------------------------
# Removing *.o *.mod files
#
#
# ---------------------------------------------------------------
# NetCDF converters build number 1 is preprocess
#  Makefile is ready.
# gfortran -O2 -ffree-line-length-none -I/usr/local/Cellar/netcdf/4.6.3_1/include  -c	../../../assimilation_code/modules/utilities/types_mod.f90
# gfortran -O2 -ffree-line-length-none -I/usr/local/Cellar/netcdf/4.6.3_1/include  -c	../../../assimilation_code/modules/utilities/utilities_mod.f90
# gfortran -O2 -ffree-line-length-none -I/usr/local/Cellar/netcdf/4.6.3_1/include  -c	../../../assimilation_code/programs/preprocess/preprocess.f90
# gfortran -O2 -ffree-line-length-none -I/usr/local/Cellar/netcdf/4.6.3_1/include  -c	../../../assimilation_code/modules/utilities/time_manager_mod.f90
# gfortran -O2 -ffree-line-length-none -I/usr/local/Cellar/netcdf/4.6.3_1/include  -c	../../../assimilation_code/modules/utilities/null_mpi_utilities_mod.f90
# gfortran preprocess.o null_mpi_utilities_mod.o types_mod.o time_manager_mod.o utilities_mod.o -o preprocess  -O2 -ffree-line-length-none -I/usr/local/Cellar/netcdf/4.6.3_1/include -L/usr/local/Cellar/netcdf/4.6.3_1/lib -lnetcdff -lnetcdf
#
#  --------------------------------------
#  Starting ... at YYYY MM DD HH MM SS =
#                  2019  9 19 14  0 10
#  Program preprocess
#  --------------------------------------
#
#   set_nml_output No echo of NML values
#  ERROR FROM:
#   find_namelist_in_file
#   routine: find_namelist_in_file
#   message:  Namelist entry &preprocess_nml must exist in file input.nml
#
#   source file: $URL: https://svn-dares-dart.cgd.ucar.edu/DART/releases/Manhattan/assimilation_code/modules/utilities/utilities_mod.f90 $
#   file revision: $Revision: 13137 $
#   revision date: $Date: 2019-04-30 08:48:00 -0700 (Tue, 30 Apr 2019) $
# .......
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-44-bd3ddacd6cbb> in <module>
# ----> 1 get_ipython().run_cell_magic('script', 'bash -s "$work_dir" "$compile_convert_nc"', 'cd $1\ncsh $2\n')
#
# /usr/local/anaconda3/envs/geosci/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# -> 2359                 result = fn(*args, **kwargs)
#    2360             return result
#    2361
#
# </usr/local/anaconda3/envs/geosci/lib/python3.7/site-packages/decorator.py:decorator-gen-110> in shebang(self, line, cell)
#
# /usr/local/anaconda3/envs/geosci/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/anaconda3/envs/geosci/lib/python3.7/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'cd $1\ncsh $2\n'' returned non-zero exit status 99.

# %% [markdown]
# ***************
# - Run: ```convert_nc``` to convert the observation file in NetCDF to DART format

# %%
# %%script bash -s "$obs_convert_dir" "$convert_nc"
# cd $1
# $2
# Out:
#  --------------------------------------
#  Starting ... at YYYY MM DD HH MM SS =
#                  2019  9 19 13 25 31
#  Program convert_nc
#  --------------------------------------
#
#   set_nml_output Echo NML values to log file only
#   write_obs_seq  opening formatted observation sequence file "../dart_inout/obs_seq_pflotran.out"
#   write_obs_seq  closed observation sequence file "../dart_inout/obs_seq_pflotran.out"
#
#  --------------------------------------
#  Finished ... at YYYY MM DD HH MM SS =
#                  2019  9 19 13 25 33
#  --------------------------------------

# %% [markdown]
# ## Run ```check_model_mod```
# - Run shell script: ```check_model_mod.csh``` to check the model_mod.F90 interface

# %%
# %%script bash -s "$work_dir" "$compile_model_check_mod"
# cd $1
# csh $2
# Out:
# ---------------------------------------------------------------
# pflotran build number 1 is preprocess
# gfortran -O2 -ffree-line-length-none -I/usr/local/Cellar/netcdf/4.6.3_1/include  -c	../../../assimilation_code/modules/utilities/types_mod.f90
# gfortran -O2 -ffree-line-length-none -I/usr/local/Cellar/netcdf/4.6.3_1/include  -c	../../../assimilation_code/modules/utilities/utilities_mod.f90
# gfortran -O2 -ffree-line-length-none -I/usr/local/Cellar/netcdf/4.6.3_1/include  -c	../../../assimilation_code/modules/utilities/time_manager_mod.f90
# gfortran -O2 -ffree-line-length-none -I/usr/local/Cellar/netcdf/4.6.3_1/include  -c	../../../assimilation_code/modules/utilities/null_mpi_utilities_mod.f90
# gfortran -O2 -ffree-line-length-none -I/usr/local/Cellar/netcdf/4.6.3_1/include  -c	../../../assimilation_code/modules/utilities/sort_mod.f90
# gfortran -O2 -ffree-line-length-none -I/usr/local/Cellar/netcdf/4.6.3_1/include  -c	../../../assimilation_code/modules/utilities/ensemble_manager_mod.f90
# gfortran -O2 -ffree-line-length-none -I/usr/local/Cellar/netcdf/4.6.3_1/include  -c	../../../assimilation_code/modules/utilities/random_seq_mod.f90
# gfortran -O2 -ffree-line-length-none -I/usr/local/Cellar/netcdf/4.6.3_1/include  -c	../../../assimilation_code/modules/observations/obs_kind_mod.f90
# rm: No match.
# mkmf_preprocess: No such file or directory.
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:492:7:
#
#   492 | integer, parameter :: max_defined_quantities = 375
#       |       1
# Error: PARAMETER at (1) is missing an initializer
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:587:63:
#
#   587 | type(obs_kind_type) :: obs_kind_names(0:max_defined_quantities)
#       |                                                               1
# Error: Explicit shaped array with nonconstant bounds at (1)
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:1168:53:
#
#  1168 | get_name_for_quantity = obs_kind_names(obs_kind_ind)%name
#       |                                                     1
# Error: Symbol 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:1220:46:
#
#  1220 |    if(trim(string1) == trim(obs_kind_names(i)%name)) then
#       |                                              1
# Error: Symbol 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:1223:6:
#
#  1223 |    end if
#       |      1
# Error: Expecting END DO statement at (1)
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:1254:43:
#
#  1254 | get_num_quantities = max_defined_quantities
#       |                                           1
# Error: Symbol 'max_defined_quantities' at (1) has no IMPLICIT type; did you mean 'get_num_quantities'?
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:1219:32:
#
#  1219 | do i = 0, max_defined_quantities
#       |                                1
# Error: Symbol 'max_defined_quantities' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:1161:63:
#
#  1161 | if (obs_kind_ind < 0 .or. obs_kind_ind > max_defined_quantities) then
#       |                                                               1
# Error: Symbol 'max_defined_quantities' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:640:32:
#
#   640 | do i = 0, max_defined_quantities
#       |                                1
# Error: Symbol 'max_defined_quantities' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:629:39:
#
#   629 |     'FLOW_FLUX', QTY_PFLOTRAN_FLOW_FLUX, .false., .false., .false.)
#       |                                       1
# Error: Symbol 'qty_pflotran_flow_flux' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:934:57:
#
#   934 | obs_kind_names(373) = obs_kind_type(QTY_PFLOTRAN_FLOWFLUX, 'QTY_PFLOTRAN_FLOWFLUX')
#       |                                                         1
# Error: Symbol 'qty_pflotran_flowflux' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:933:64:
#
#   933 | obs_kind_names(372) = obs_kind_type(QTY_PFLOTRAN_LIQUID_PRESSURE, 'QTY_PFLOTRAN_LIQUID_PRESSURE')
#       |                                                                1
# Error: Symbol 'qty_pflotran_liquid_pressure' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:932:66:
#
#   932 | obs_kind_names(371) = obs_kind_type(QTY_PFLOTRAN_LIQUID_SATURATION, 'QTY_PFLOTRAN_LIQUID_SATURATION')
#       |                                                                  1
# Error: Symbol 'qty_pflotran_liquid_saturation' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:929:61:
#
#   929 | obs_kind_names(368) = obs_kind_type(QTY_PFLOTRAN_PERMEABILITY, 'QTY_PFLOTRAN_PERMEABILITY')
#       |                                                             1
# Error: Symbol 'qty_pflotran_permeability' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:631:37:
#
#   631 |     'POROSITY', QTY_PFLOTRAN_POROSITY, .false., .false., .false.)
#       |                                     1
# Error: Symbol 'qty_pflotran_porosity' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:627:43:
#
#   627 |     'TEMPERATURE', QTY_PFLOTRAN_TEMPERATURE, .false., .false., .false.)
#       |                                           1
# Error: Symbol 'qty_pflotran_temperature' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:633:61:
#
#   633 |     'THERMAL_CONDUCTIVITY', QTY_PFLOTRAN_THERMAL_CONDUCTIVITY, .false., .false., .false.)
#       |                                                             1
# Error: Symbol 'qty_pflotran_thermal_conductivity' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:931:68:
#
#   931 | obs_kind_names(370) = obs_kind_type(QTY_PFLOTRAN_THERMALCONDUCTIVITY, 'QTY_PFLOTRAN_THERMALCONDUCTIVITY')
#       |                                                                    1
# Error: Symbol 'qty_pflotran_thermalconductivity' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:641:3:
#
#   641 |    obs_kind_names(i) = obs_kind_type(i, 'UNKNOWN')
#       |   1
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:644:0:
#
#   644 | obs_kind_names( 0) = obs_kind_type(QTY_STATE_VARIABLE, 'QTY_STATE_VARIABLE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:645:0:
#
#   645 | obs_kind_names( 1) = obs_kind_type(QTY_U_WIND_COMPONENT, 'QTY_U_WIND_COMPONENT')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:646:0:
#
#   646 | obs_kind_names( 2) = obs_kind_type(QTY_V_WIND_COMPONENT, 'QTY_V_WIND_COMPONENT')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:647:0:
#
#   647 | obs_kind_names( 3) = obs_kind_type(QTY_SURFACE_PRESSURE, 'QTY_SURFACE_PRESSURE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:648:0:
#
#   648 | obs_kind_names( 4) = obs_kind_type(QTY_TEMPERATURE, 'QTY_TEMPERATURE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:649:0:
#
#   649 | obs_kind_names( 5) = obs_kind_type(QTY_SPECIFIC_HUMIDITY, 'QTY_SPECIFIC_HUMIDITY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:650:0:
#
#   650 | obs_kind_names( 6) = obs_kind_type(QTY_PRESSURE, 'QTY_PRESSURE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:651:0:
#
#   651 | obs_kind_names( 7) = obs_kind_type(QTY_VERTICAL_VELOCITY, 'QTY_VERTICAL_VELOCITY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:652:0:
#
#   652 | obs_kind_names( 8) = obs_kind_type(QTY_RAINWATER_MIXING_RATIO, 'QTY_RAINWATER_MIXING_RATIO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:653:0:
#
#   653 | obs_kind_names( 9) = obs_kind_type(QTY_DEWPOINT, 'QTY_DEWPOINT')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:654:0:
#
#   654 | obs_kind_names(10) = obs_kind_type(QTY_DENSITY, 'QTY_DENSITY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:655:0:
#
#   655 | obs_kind_names(11) = obs_kind_type(QTY_VELOCITY, 'QTY_VELOCITY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:656:0:
#
#   656 | obs_kind_names(12) = obs_kind_type(QTY_RADAR_REFLECTIVITY, 'QTY_RADAR_REFLECTIVITY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:657:0:
#
#   657 | obs_kind_names(13) = obs_kind_type(QTY_1D_INTEGRAL, 'QTY_1D_INTEGRAL')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:658:0:
#
#   658 | obs_kind_names(14) = obs_kind_type(QTY_GRAUPEL_MIXING_RATIO, 'QTY_GRAUPEL_MIXING_RATIO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:659:0:
#
#   659 | obs_kind_names(15) = obs_kind_type(QTY_SNOW_MIXING_RATIO, 'QTY_SNOW_MIXING_RATIO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:660:0:
#
#   660 | obs_kind_names(16) = obs_kind_type(QTY_GPSRO, 'QTY_GPSRO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:661:0:
#
#   661 | obs_kind_names(17) = obs_kind_type(QTY_CLOUD_LIQUID_WATER, 'QTY_CLOUD_LIQUID_WATER')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:662:0:
#
#   662 | obs_kind_names(18) = obs_kind_type(QTY_CLOUD_ICE, 'QTY_CLOUD_ICE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:663:0:
#
#   663 | obs_kind_names(19) = obs_kind_type(QTY_CONDENSATIONAL_HEATING, 'QTY_CONDENSATIONAL_HEATING')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:664:0:
#
#   664 | obs_kind_names(20) = obs_kind_type(QTY_VAPOR_MIXING_RATIO, 'QTY_VAPOR_MIXING_RATIO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:665:0:
#
#   665 | obs_kind_names(21) = obs_kind_type(QTY_ICE_NUMBER_CONCENTRATION, 'QTY_ICE_NUMBER_CONCENTRATION')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:666:0:
#
#   666 | obs_kind_names(22) = obs_kind_type(QTY_GEOPOTENTIAL_HEIGHT, 'QTY_GEOPOTENTIAL_HEIGHT')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:667:0:
#
#   667 | obs_kind_names(23) = obs_kind_type(QTY_POTENTIAL_TEMPERATURE, 'QTY_POTENTIAL_TEMPERATURE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:668:0:
#
#   668 | obs_kind_names(24) = obs_kind_type(QTY_SOIL_MOISTURE, 'QTY_SOIL_MOISTURE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:669:0:
#
#   669 | obs_kind_names(25) = obs_kind_type(QTY_SURFACE_ELEVATION, 'QTY_SURFACE_ELEVATION')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:670:0:
#
#   670 | obs_kind_names(26) = obs_kind_type(QTY_GRAV_WAVE_DRAG_EFFIC, 'QTY_GRAV_WAVE_DRAG_EFFIC')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:671:0:
#
#   671 | obs_kind_names(27) = obs_kind_type(QTY_GRAV_WAVE_STRESS_FRACTION, 'QTY_GRAV_WAVE_STRESS_FRACTION')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:672:0:
#
#   672 | obs_kind_names(28) = obs_kind_type(QTY_TRACER_SOURCE, 'QTY_TRACER_SOURCE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:673:0:
#
#   673 | obs_kind_names(29) = obs_kind_type(QTY_TRACER_CONCENTRATION, 'QTY_TRACER_CONCENTRATION')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:674:0:
#
#   674 | obs_kind_names(30) = obs_kind_type(QTY_MEAN_SOURCE, 'QTY_MEAN_SOURCE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:675:0:
#
#   675 | obs_kind_names(31) = obs_kind_type(QTY_SOURCE_PHASE, 'QTY_SOURCE_PHASE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:676:0:
#
#   676 | obs_kind_names(32) = obs_kind_type(QTY_POWER_WEIGHTED_FALL_SPEED, 'QTY_POWER_WEIGHTED_FALL_SPEED')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:677:0:
#
#   677 | obs_kind_names(33) = obs_kind_type(QTY_CLOUDWATER_MIXING_RATIO, 'QTY_CLOUDWATER_MIXING_RATIO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:678:0:
#
#   678 | obs_kind_names(34) = obs_kind_type(QTY_ICE_MIXING_RATIO, 'QTY_ICE_MIXING_RATIO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:679:0:
#
#   679 | obs_kind_names(35) = obs_kind_type(QTY_DROPLET_NUMBER_CONCENTR, 'QTY_DROPLET_NUMBER_CONCENTR')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:680:0:
#
#   680 | obs_kind_names(36) = obs_kind_type(QTY_SNOW_NUMBER_CONCENTR, 'QTY_SNOW_NUMBER_CONCENTR')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:681:0:
#
#   681 | obs_kind_names(37) = obs_kind_type(QTY_RAIN_NUMBER_CONCENTR, 'QTY_RAIN_NUMBER_CONCENTR')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:682:0:
#
#   682 | obs_kind_names(38) = obs_kind_type(QTY_GRAUPEL_NUMBER_CONCENTR, 'QTY_GRAUPEL_NUMBER_CONCENTR')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:683:0:
#
#   683 | obs_kind_names(39) = obs_kind_type(QTY_CLOUD_FRACTION, 'QTY_CLOUD_FRACTION')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:684:0:
#
#   684 | obs_kind_names(40) = obs_kind_type(QTY_ICE_FRACTION, 'QTY_ICE_FRACTION')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:685:0:
#
#   685 | obs_kind_names(41) = obs_kind_type(QTY_RELATIVE_HUMIDITY, 'QTY_RELATIVE_HUMIDITY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:686:0:
#
#   686 | obs_kind_names(42) = obs_kind_type(QTY_ELECTRON_DENSITY, 'QTY_ELECTRON_DENSITY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:687:0:
#
#   687 | obs_kind_names(43) = obs_kind_type(QTY_1D_PARAMETER, 'QTY_1D_PARAMETER')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:688:0:
#
#   688 | obs_kind_names(44) = obs_kind_type(QTY_2D_PARAMETER, 'QTY_2D_PARAMETER')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:689:0:
#
#   689 | obs_kind_names(45) = obs_kind_type(QTY_3D_PARAMETER, 'QTY_3D_PARAMETER')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:690:0:
#
#   690 | obs_kind_names(46) = obs_kind_type(QTY_ATOMIC_OXYGEN_MIXING_RATIO, 'QTY_ATOMIC_OXYGEN_MIXING_RATIO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:691:0:
#
#   691 | obs_kind_names(47) = obs_kind_type(QTY_MOLEC_OXYGEN_MIXING_RATIO, 'QTY_MOLEC_OXYGEN_MIXING_RATIO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:692:0:
#
#   692 | obs_kind_names(48) = obs_kind_type(QTY_ALTIMETER_TENDENCY, 'QTY_ALTIMETER_TENDENCY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:693:0:
#
#   693 | obs_kind_names(49) = obs_kind_type(QTY_PRECIPITABLE_WATER, 'QTY_PRECIPITABLE_WATER')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:694:0:
#
#   694 | obs_kind_names(50) = obs_kind_type(QTY_SALINITY, 'QTY_SALINITY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:695:0:
#
#   695 | obs_kind_names(51) = obs_kind_type(QTY_U_CURRENT_COMPONENT, 'QTY_U_CURRENT_COMPONENT')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:696:0:
#
#   696 | obs_kind_names(52) = obs_kind_type(QTY_V_CURRENT_COMPONENT, 'QTY_V_CURRENT_COMPONENT')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:697:0:
#
#   697 | obs_kind_names(53) = obs_kind_type(QTY_SEA_SURFACE_HEIGHT, 'QTY_SEA_SURFACE_HEIGHT')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:698:0:
#
#   698 | obs_kind_names(54) = obs_kind_type(QTY_DRY_LAND, 'QTY_DRY_LAND')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:699:0:
#
#   699 | obs_kind_names(55) = obs_kind_type(QTY_SEA_SURFACE_PRESSURE, 'QTY_SEA_SURFACE_PRESSURE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:700:0:
#
#   700 | obs_kind_names(56) = obs_kind_type(QTY_W_CURRENT_COMPONENT, 'QTY_W_CURRENT_COMPONENT')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:701:0:
#
#   701 | obs_kind_names(57) = obs_kind_type(QTY_OCCULTATION_REFRACTIVITY, 'QTY_OCCULTATION_REFRACTIVITY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:702:0:
#
#   702 | obs_kind_names(58) = obs_kind_type(QTY_OCCULTATION_EXCESSPHASE, 'QTY_OCCULTATION_EXCESSPHASE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:703:0:
#
#   703 | obs_kind_names(59) = obs_kind_type(QTY_GEOMETRIC_HEIGHT, 'QTY_GEOMETRIC_HEIGHT')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:704:0:
#
#   704 | obs_kind_names(60) = obs_kind_type(QTY_INFRARED_RADIANCE, 'QTY_INFRARED_RADIANCE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:705:0:
#
#   705 | obs_kind_names(61) = obs_kind_type(QTY_INFRARED_BRIGHT_TEMP, 'QTY_INFRARED_BRIGHT_TEMP')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:706:0:
#
#   706 | obs_kind_names(62) = obs_kind_type(QTY_LANDMASK, 'QTY_LANDMASK')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:707:0:
#
#   707 | obs_kind_names(63) = obs_kind_type(QTY_EDGE_NORMAL_SPEED, 'QTY_EDGE_NORMAL_SPEED')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:708:0:
#
#   708 | obs_kind_names(64) = obs_kind_type(QTY_CLW_PATH, 'QTY_CLW_PATH')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:709:0:
#
#   709 | obs_kind_names(65) = obs_kind_type(QTY_WIND_TURBINE_POWER, 'QTY_WIND_TURBINE_POWER')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:710:0:
#
#   710 | obs_kind_names(66) = obs_kind_type(QTY_2M_SPECIFIC_HUMIDITY, 'QTY_2M_SPECIFIC_HUMIDITY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:711:0:
#
#   711 | obs_kind_names(67) = obs_kind_type(QTY_2M_TEMPERATURE, 'QTY_2M_TEMPERATURE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:712:0:
#
#   712 | obs_kind_names(68) = obs_kind_type(QTY_10M_U_WIND_COMPONENT, 'QTY_10M_U_WIND_COMPONENT')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:713:0:
#
#   713 | obs_kind_names(69) = obs_kind_type(QTY_10M_V_WIND_COMPONENT, 'QTY_10M_V_WIND_COMPONENT')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:714:0:
#
#   714 | obs_kind_names(70) = obs_kind_type(QTY_SKIN_TEMPERATURE, 'QTY_SKIN_TEMPERATURE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:715:0:
#
#   715 | obs_kind_names(71) = obs_kind_type(QTY_NADIR_RADIANCE, 'QTY_NADIR_RADIANCE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:716:0:
#
#   716 | obs_kind_names(72) = obs_kind_type(QTY_TRACER_1_MIXING_RATIO, 'QTY_TRACER_1_MIXING_RATIO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:717:0:
#
#   717 | obs_kind_names(73) = obs_kind_type(QTY_TRACER_2_MIXING_RATIO, 'QTY_TRACER_2_MIXING_RATIO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:718:0:
#
#   718 | obs_kind_names(74) = obs_kind_type(QTY_SOIL_TEMPERATURE, 'QTY_SOIL_TEMPERATURE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:719:0:
#
#   719 | obs_kind_names(75) = obs_kind_type(QTY_SOIL_LIQUID_WATER, 'QTY_SOIL_LIQUID_WATER')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:720:0:
#
#   720 | obs_kind_names(76) = obs_kind_type(QTY_VERTICAL_VORTICITY, 'QTY_VERTICAL_VORTICITY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:721:0:
#
#   721 | obs_kind_names(77) = obs_kind_type(QTY_SURFACE_ALBEDO, 'QTY_SURFACE_ALBEDO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:722:0:
#
#   722 | obs_kind_names(78) = obs_kind_type(QTY_SURFACE_EMISSIVITY, 'QTY_SURFACE_EMISSIVITY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:723:0:
#
#   723 | obs_kind_names(79) = obs_kind_type(QTY_DUST_OPACITY_7MB, 'QTY_DUST_OPACITY_7MB')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:724:0:
#
#   724 | obs_kind_names(80) = obs_kind_type(QTY_THC, 'QTY_THC')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:725:0:
#
#   725 | obs_kind_names(81) = obs_kind_type(QTY_VORTEX_LON, 'QTY_VORTEX_LON')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:726:0:
#
#   726 | obs_kind_names(82) = obs_kind_type(QTY_VORTEX_LAT, 'QTY_VORTEX_LAT')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:727:0:
#
#   727 | obs_kind_names(83) = obs_kind_type(QTY_VORTEX_PMIN, 'QTY_VORTEX_PMIN')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:728:0:
#
#   728 | obs_kind_names(84) = obs_kind_type(QTY_VORTEX_WMAX, 'QTY_VORTEX_WMAX')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:729:0:
#
#   729 | obs_kind_names(85) = obs_kind_type(QTY_EXNER_FUNCTION, 'QTY_EXNER_FUNCTION')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:730:0:
#
#   730 | obs_kind_names(86) = obs_kind_type(QTY_TURBULENT_KINETIC_ENERGY, 'QTY_TURBULENT_KINETIC_ENERGY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:731:0:
#
#   731 | obs_kind_names(87) = obs_kind_type(QTY_TOTAL_PRECIPITABLE_WATER, 'QTY_TOTAL_PRECIPITABLE_WATER')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:732:0:
#
#   732 | obs_kind_names(88) = obs_kind_type(QTY_VERTLEVEL, 'QTY_VERTLEVEL')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:733:0:
#
#   733 | obs_kind_names(89) = obs_kind_type(QTY_MICROWAVE_BRIGHT_TEMP, 'QTY_MICROWAVE_BRIGHT_TEMP')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:734:0:
#
#   734 | obs_kind_names(90) = obs_kind_type(QTY_INTEGRATED_SULFATE, 'QTY_INTEGRATED_SULFATE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:735:0:
#
#   735 | obs_kind_names(91) = obs_kind_type(QTY_INTEGRATED_DUST, 'QTY_INTEGRATED_DUST')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:736:0:
#
#   736 | obs_kind_names(92) = obs_kind_type(QTY_INTEGRATED_SMOKE, 'QTY_INTEGRATED_SMOKE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:737:0:
#
#   737 | obs_kind_names(93) = obs_kind_type(QTY_INTEGRATED_SEASALT, 'QTY_INTEGRATED_SEASALT')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:738:0:
#
#   738 | obs_kind_names(94) = obs_kind_type(QTY_INTEGRATED_AOD, 'QTY_INTEGRATED_AOD')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:739:0:
#
#   739 | obs_kind_names(95) = obs_kind_type(QTY_SO2, 'QTY_SO2')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:740:0:
#
#   740 | obs_kind_names(96) = obs_kind_type(QTY_SULFATE, 'QTY_SULFATE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:741:0:
#
#   741 | obs_kind_names(97) = obs_kind_type(QTY_DUST, 'QTY_DUST')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:742:0:
#
#   742 | obs_kind_names(98) = obs_kind_type(QTY_SMOKE, 'QTY_SMOKE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:743:0:
#
#   743 | obs_kind_names(99) = obs_kind_type(QTY_SEASALT, 'QTY_SEASALT')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:744:0:
#
#   744 | obs_kind_names(100) = obs_kind_type(QTY_HAIL_MIXING_RATIO, 'QTY_HAIL_MIXING_RATIO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:745:0:
#
#   745 | obs_kind_names(101) = obs_kind_type(QTY_HAIL_NUMBER_CONCENTR, 'QTY_HAIL_NUMBER_CONCENTR')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:746:0:
#
#   746 | obs_kind_names(102) = obs_kind_type(QTY_GRAUPEL_VOLUME, 'QTY_GRAUPEL_VOLUME')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:747:0:
#
#   747 | obs_kind_names(103) = obs_kind_type(QTY_HAIL_VOLUME, 'QTY_HAIL_VOLUME')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:748:0:
#
#   748 | obs_kind_names(104) = obs_kind_type(QTY_DIFFERENTIAL_REFLECTIVITY, 'QTY_DIFFERENTIAL_REFLECTIVITY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:749:0:
#
#   749 | obs_kind_names(105) = obs_kind_type(QTY_SPECIFIC_DIFFERENTIAL_PHASE, 'QTY_SPECIFIC_DIFFERENTIAL_PHASE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:750:0:
#
#   750 | obs_kind_names(106) = obs_kind_type(QTY_FLASH_RATE_2D, 'QTY_FLASH_RATE_2D')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:752:0:
#
#   752 | obs_kind_names(107) = obs_kind_type(QTY_SNOW_THICKNESS        ,'QTY_SNOW_THICKNESS')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:753:0:
#
#   753 | obs_kind_names(108) = obs_kind_type(QTY_SNOW_WATER            ,'QTY_SNOW_WATER')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:754:0:
#
#   754 | obs_kind_names(109) = obs_kind_type(QTY_SNOWCOVER_FRAC        ,'QTY_SNOWCOVER_FRAC')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:755:0:
#
#   755 | obs_kind_names(110) = obs_kind_type(QTY_LIQUID_WATER          ,'QTY_LIQUID_WATER')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:756:0:
#
#   756 | obs_kind_names(111) = obs_kind_type(QTY_ICE                   ,'QTY_ICE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:757:0:
#
#   757 | obs_kind_names(112) = obs_kind_type(QTY_CARBON                ,'QTY_CARBON')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:758:0:
#
#   758 | obs_kind_names(113) = obs_kind_type(QTY_SOIL_CARBON           ,'QTY_SOIL_CARBON')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:759:0:
#
#   759 | obs_kind_names(114) = obs_kind_type(QTY_ROOT_CARBON           ,'QTY_ROOT_CARBON')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:760:0:
#
#   760 | obs_kind_names(115) = obs_kind_type(QTY_STEM_CARBON           ,'QTY_STEM_CARBON')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:761:0:
#
#   761 | obs_kind_names(116) = obs_kind_type(QTY_LEAF_CARBON           ,'QTY_LEAF_CARBON')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:762:0:
#
#   762 | obs_kind_names(117) = obs_kind_type(QTY_LEAF_AREA_INDEX       ,'QTY_LEAF_AREA_INDEX')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:763:0:
#
#   763 | obs_kind_names(118) = obs_kind_type(QTY_NET_CARBON_FLUX       ,'QTY_NET_CARBON_FLUX')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:764:0:
#
#   764 | obs_kind_names(119) = obs_kind_type(QTY_LATENT_HEAT_FLUX      ,'QTY_LATENT_HEAT_FLUX')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:765:0:
#
#   765 | obs_kind_names(120) = obs_kind_type(QTY_SENSIBLE_HEAT_FLUX    ,'QTY_SENSIBLE_HEAT_FLUX')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:766:0:
#
#   766 | obs_kind_names(121) = obs_kind_type(QTY_RADIATION             ,'QTY_RADIATION')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:767:0:
#
#   767 | obs_kind_names(122) = obs_kind_type(QTY_NET_CARBON_PRODUCTION ,'QTY_NET_CARBON_PRODUCTION')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:768:0:
#
#   768 | obs_kind_names(123) = obs_kind_type(QTY_NITROGEN              ,'QTY_NITROGEN')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:769:0:
#
#   769 | obs_kind_names(124) = obs_kind_type(QTY_SOIL_NITROGEN         ,'QTY_SOIL_NITROGEN')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:770:0:
#
#   770 | obs_kind_names(125) = obs_kind_type(QTY_ROOT_NITROGEN         ,'QTY_ROOT_NITROGEN')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:771:0:
#
#   771 | obs_kind_names(126) = obs_kind_type(QTY_STEM_NITROGEN         ,'QTY_STEM_NITROGEN')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:772:0:
#
#   772 | obs_kind_names(127) = obs_kind_type(QTY_LEAF_NITROGEN         ,'QTY_LEAF_NITROGEN')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:773:0:
#
#   773 | obs_kind_names(128) = obs_kind_type(QTY_WATER_TABLE_DEPTH     ,'QTY_WATER_TABLE_DEPTH')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:774:0:
#
#   774 | obs_kind_names(129) = obs_kind_type(QTY_FPAR                  ,'QTY_FPAR')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:775:0:
#
#   775 | obs_kind_names(130) = obs_kind_type(QTY_TOTAL_WATER_STORAGE   ,'QTY_TOTAL_WATER_STORAGE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:777:0:
#
#   777 | obs_kind_names(140) = obs_kind_type(QTY_NEUTRON_INTENSITY     ,'QTY_NEUTRON_INTENSITY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:778:0:
#
#   778 | obs_kind_names(141) = obs_kind_type(QTY_CANOPY_WATER          ,'QTY_CANOPY_WATER')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:779:0:
#
#   779 | obs_kind_names(142) = obs_kind_type(QTY_GROUND_HEAT_FLUX      ,'QTY_GROUND_HEAT_FLUX')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:780:0:
#
#   780 | obs_kind_names(143) = obs_kind_type(QTY_VERTICAL_TEC          ,'QTY_VERTICAL_TEC')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:781:0:
#
#   781 | obs_kind_names(144) = obs_kind_type(QTY_O_N2_COLUMN_DENSITY_RATIO, 'QTY_O_N2_COLUMN_DENSITY_RATIO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:783:0:
#
#   783 | obs_kind_names(151) = obs_kind_type(QTY_O3,             'QTY_O3')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:784:0:
#
#   784 | obs_kind_names(153) = obs_kind_type(QTY_CO,             'QTY_CO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:785:0:
#
#   785 | obs_kind_names(155) = obs_kind_type(QTY_NO,             'QTY_NO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:786:0:
#
#   786 | obs_kind_names(156) = obs_kind_type(QTY_NO2,            'QTY_NO2')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:788:0:
#
#   788 | obs_kind_names(161) = obs_kind_type(QTY_CO01,           'QTY_CO01')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:789:0:
#
#   789 | obs_kind_names(162) = obs_kind_type(QTY_CO02,           'QTY_CO02')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:790:0:
#
#   790 | obs_kind_names(163) = obs_kind_type(QTY_CO03,           'QTY_CO03')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:792:0:
#
#   792 | obs_kind_names(170) = obs_kind_type(QTY_SFCO,           'QTY_SFCO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:793:0:
#
#   793 | obs_kind_names(171) = obs_kind_type(QTY_SFCO01,         'QTY_SFCO01')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:794:0:
#
#   794 | obs_kind_names(172) = obs_kind_type(QTY_SFCO02,         'QTY_SFCO02')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:795:0:
#
#   795 | obs_kind_names(173) = obs_kind_type(QTY_SFCO03,         'QTY_SFCO03')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:796:0:
#
#   796 | obs_kind_names(174) = obs_kind_type(QTY_STATE_VAR_POWER,'QTY_STATE_VAR_POWER')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:798:0:
#
#   798 | obs_kind_names(200) = obs_kind_type(QTY_AOD,            'QTY_AOD')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:799:0:
#
#   799 | obs_kind_names(201) = obs_kind_type(QTY_CB1,            'QTY_CB1')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:800:0:
#
#   800 | obs_kind_names(202) = obs_kind_type(QTY_CB2,            'QTY_CB2')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:801:0:
#
#   801 | obs_kind_names(203) = obs_kind_type(QTY_OC1,            'QTY_OC1')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:802:0:
#
#   802 | obs_kind_names(204) = obs_kind_type(QTY_OC2,            'QTY_OC2')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:803:0:
#
#   803 | obs_kind_names(205) = obs_kind_type(QTY_CB1,            'QTY_CB102')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:804:0:
#
#   804 | obs_kind_names(206) = obs_kind_type(QTY_CB2,            'QTY_CB202')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:805:0:
#
#   805 | obs_kind_names(207) = obs_kind_type(QTY_OC1,            'QTY_OC102')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:806:0:
#
#   806 | obs_kind_names(208) = obs_kind_type(QTY_OC2,            'QTY_OC202')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:808:0:
#
#   808 | obs_kind_names(221) = obs_kind_type(QTY_SFCB1,          'QTY_SFCB1')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:809:0:
#
#   809 | obs_kind_names(222) = obs_kind_type(QTY_SFCB2,          'QTY_SFCB2')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:810:0:
#
#   810 | obs_kind_names(223) = obs_kind_type(QTY_SFOC1,          'QTY_SFOC1')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:811:0:
#
#   811 | obs_kind_names(224) = obs_kind_type(QTY_SFOC2,          'QTY_SFOC2')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:812:0:
#
#   812 | obs_kind_names(225) = obs_kind_type(QTY_SFCB1,          'QTY_SFCB102')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:813:0:
#
#   813 | obs_kind_names(226) = obs_kind_type(QTY_SFCB2,          'QTY_SFCB202')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:814:0:
#
#   814 | obs_kind_names(227) = obs_kind_type(QTY_SFOC1,          'QTY_SFOC102')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:815:0:
#
#   815 | obs_kind_names(228) = obs_kind_type(QTY_SFOC2,          'QTY_SFOC202')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:817:0:
#
#   817 | obs_kind_names(247) = obs_kind_type(QTY_CO2,            'QTY_CO2')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:818:0:
#
#   818 | obs_kind_names(248) = obs_kind_type(QTY_NH3,            'QTY_NH3')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:819:0:
#
#   819 | obs_kind_names(249) = obs_kind_type(QTY_CH4,            'QTY_CH4')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:821:0:
#
#   821 | obs_kind_names(251) = obs_kind_type(QTY_TEMPERATURE_ELECTRON  ,'QTY_TEMPERATURE_ELECTRON')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:822:0:
#
#   822 | obs_kind_names(252) = obs_kind_type(QTY_TEMPERATURE_ION       ,'QTY_TEMPERATURE_ION')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:823:0:
#
#   823 | obs_kind_names(253) = obs_kind_type(QTY_DENSITY_NEUTRAL_O3P   ,'QTY_DENSITY_NEUTRAL_O3P')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:824:0:
#
#   824 | obs_kind_names(254) = obs_kind_type(QTY_DENSITY_NEUTRAL_O2    ,'QTY_DENSITY_NEUTRAL_O2')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:825:0:
#
#   825 | obs_kind_names(255) = obs_kind_type(QTY_DENSITY_NEUTRAL_N2    ,'QTY_DENSITY_NEUTRAL_N2')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:826:0:
#
#   826 | obs_kind_names(256) = obs_kind_type(QTY_DENSITY_NEUTRAL_N4S   ,'QTY_DENSITY_NEUTRAL_N4S')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:827:0:
#
#   827 | obs_kind_names(257) = obs_kind_type(QTY_DENSITY_NEUTRAL_NO    ,'QTY_DENSITY_NEUTRAL_NO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:828:0:
#
#   828 | obs_kind_names(258) = obs_kind_type(QTY_DENSITY_NEUTRAL_N2D   ,'QTY_DENSITY_NEUTRAL_N2D')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:829:0:
#
#   829 | obs_kind_names(259) = obs_kind_type(QTY_DENSITY_NEUTRAL_N2P   ,'QTY_DENSITY_NEUTRAL_N2P')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:830:0:
#
#   830 | obs_kind_names(260) = obs_kind_type(QTY_DENSITY_NEUTRAL_H     ,'QTY_DENSITY_NEUTRAL_H')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:831:0:
#
#   831 | obs_kind_names(261) = obs_kind_type(QTY_DENSITY_NEUTRAL_HE    ,'QTY_DENSITY_NEUTRAL_HE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:832:0:
#
#   832 | obs_kind_names(262) = obs_kind_type(QTY_DENSITY_NEUTRAL_CO2   ,'QTY_DENSITY_NEUTRAL_CO2')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ...
#
#   874 | obs_kind_names(315) = obs_kind_type(QTY_SEAICE_AGREG_SNOWDEPTH,'QTY_SEAICE_AGREG_SNOWDEPTH')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:875:0:
#
#   875 | obs_kind_names(316) = obs_kind_type(QTY_U_SEAICE_COMPONENT    ,'QTY_U_SEAICE_COMPONENT')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:876:0:
#
#   876 | obs_kind_names(317) = obs_kind_type(QTY_V_SEAICE_COMPONENT    ,'QTY_V_SEAICE_COMPONENT')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:877:0:
#
#   877 | obs_kind_names(318) = obs_kind_type(QTY_SEAICE_ALBEDODIRVIZ   ,'QTY_SEAICE_ALBEDODIRVIZ')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:878:0:
#
#   878 | obs_kind_names(319) = obs_kind_type(QTY_SEAICE_ALBEDODIRNIR   ,'QTY_SEAICE_ALBEDODIRNIR')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:879:0:
#
#   879 | obs_kind_names(320) = obs_kind_type(QTY_SEAICE_ALBEDOINDVIZ   ,'QTY_SEAICE_ALBEDOINDVIZ')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:880:0:
#
#   880 | obs_kind_names(321) = obs_kind_type(QTY_SEAICE_ALBEDOINDNIR   ,'QTY_SEAICE_ALBEDOINDNIR')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:881:0:
#
#   881 | obs_kind_names(322) = obs_kind_type(QTY_SEAICE_CONCENTR       ,'QTY_SEAICE_CONCENTR')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:882:0:
#
#   882 | obs_kind_names(323) = obs_kind_type(QTY_SEAICE_VOLUME         ,'QTY_SEAICE_VOLUME')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:883:0:
#
#   883 | obs_kind_names(324) = obs_kind_type(QTY_SEAICE_SNOWVOLUME     ,'QTY_SEAICE_SNOWVOLUME')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:884:0:
#
#   884 | obs_kind_names(325) = obs_kind_type(QTY_SEAICE_SURFACETEMP    ,'QTY_SEAICE_SURFACETEMP')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:885:0:
#
#   885 | obs_kind_names(326) = obs_kind_type(QTY_SEAICE_FIRSTYEARAREA  ,'QTY_SEAICE_FIRSTYEARAREA')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:886:0:
#
#   886 | obs_kind_names(327) = obs_kind_type(QTY_SEAICE_ICEAGE         ,'QTY_SEAICE_ICEAGE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:887:0:
#
#   887 | obs_kind_names(328) = obs_kind_type(QTY_SEAICE_LEVELAREA      ,'QTY_SEAICE_LEVELAREA')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:888:0:
#
#   888 | obs_kind_names(329) = obs_kind_type(QTY_SEAICE_LEVELVOLUME    ,'QTY_SEAICE_LEVELVOLUME')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:889:0:
#
#   889 | obs_kind_names(330) = obs_kind_type(QTY_SEAICE_MELTPONDAREA   ,'QTY_SEAICE_MELTPONDAREA')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:890:0:
#
#   890 | obs_kind_names(331) = obs_kind_type(QTY_SEAICE_MELTPONDDEPTH  ,'QTY_SEAICE_MELTPONDDEPTH')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:891:0:
#
#   891 | obs_kind_names(332) = obs_kind_type(QTY_SEAICE_MELTPONDLID    ,'QTY_SEAICE_MELTPONDLID')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:892:0:
#
#   892 | obs_kind_names(333) = obs_kind_type(QTY_SEAICE_MELTPONDSNOW   ,'QTY_SEAICE_MELTPONDSNOW')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:893:0:
#
#   893 | obs_kind_names(334) = obs_kind_type(QTY_SEAICE_SALINITY001    ,'QTY_SEAICE_SALINITY001')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:894:0:
#
#   894 | obs_kind_names(335) = obs_kind_type(QTY_SEAICE_SALINITY002    ,'QTY_SEAICE_SALINITY002')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:895:0:
#
#   895 | obs_kind_names(336) = obs_kind_type(QTY_SEAICE_SALINITY003    ,'QTY_SEAICE_SALINITY003')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:896:0:
#
#   896 | obs_kind_names(337) = obs_kind_type(QTY_SEAICE_SALINITY004    ,'QTY_SEAICE_SALINITY004')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:897:0:
#
#   897 | obs_kind_names(338) = obs_kind_type(QTY_SEAICE_SALINITY005    ,'QTY_SEAICE_SALINITY005')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:898:0:
#
#   898 | obs_kind_names(339) = obs_kind_type(QTY_SEAICE_SALINITY006    ,'QTY_SEAICE_SALINITY006')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:899:0:
#
#   899 | obs_kind_names(340) = obs_kind_type(QTY_SEAICE_SALINITY007    ,'QTY_SEAICE_SALINITY007')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:900:0:
#
#   900 | obs_kind_names(341) = obs_kind_type(QTY_SEAICE_SALINITY008    ,'QTY_SEAICE_SALINITY008')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:901:0:
#
#   901 | obs_kind_names(342) = obs_kind_type(QTY_SEAICE_ICEENTHALPY001 ,'QTY_SEAICE_ICEENTHALPY001')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:902:0:
#
#   902 | obs_kind_names(343) = obs_kind_type(QTY_SEAICE_ICEENTHALPY002 ,'QTY_SEAICE_ICEENTHALPY002')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:903:0:
#
#   903 | obs_kind_names(344) = obs_kind_type(QTY_SEAICE_ICEENTHALPY003 ,'QTY_SEAICE_ICEENTHALPY003')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:904:0:
#
#   904 | obs_kind_names(345) = obs_kind_type(QTY_SEAICE_ICEENTHALPY004 ,'QTY_SEAICE_ICEENTHALPY004')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:905:0:
#
#   905 | obs_kind_names(346) = obs_kind_type(QTY_SEAICE_ICEENTHALPY005 ,'QTY_SEAICE_ICEENTHALPY005')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:906:0:
#
#   906 | obs_kind_names(347) = obs_kind_type(QTY_SEAICE_ICEENTHALPY006 ,'QTY_SEAICE_ICEENTHALPY006')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:907:0:
#
#   907 | obs_kind_names(348) = obs_kind_type(QTY_SEAICE_ICEENTHALPY007 ,'QTY_SEAICE_ICEENTHALPY007')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:908:0:
#
#   908 | obs_kind_names(349) = obs_kind_type(QTY_SEAICE_ICEENTHALPY008 ,'QTY_SEAICE_ICEENTHALPY008')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:909:0:
#
#   909 | obs_kind_names(350) = obs_kind_type(QTY_SEAICE_SNOWENTHALPY001,'QTY_SEAICE_SNOWENTHALPY001')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:910:0:
#
#   910 | obs_kind_names(351) = obs_kind_type(QTY_SEAICE_SNOWENTHALPY002,'QTY_SEAICE_SNOWENTHALPY002')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:911:0:
#
#   911 | obs_kind_names(352) = obs_kind_type(QTY_SEAICE_SNOWENTHALPY003,'QTY_SEAICE_SNOWENTHALPY003')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:912:0:
#
#   912 | obs_kind_names(353) = obs_kind_type(QTY_SOM_TEMPERATURE,       'QTY_SOM_TEMPERATURE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:913:0:
#
#   913 | obs_kind_names(354) = obs_kind_type(QTY_SEAICE_FY,             'QTY_SEAICE_FY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:914:0:
#
#   914 | obs_kind_names(355) = obs_kind_type(QTY_SEAICE_AGREG_FY,       'QTY_SEAICE_AGREG_FY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:915:0:
#
#   915 | obs_kind_names(356) = obs_kind_type(QTY_SEAICE_AGREG_SURFACETEMP,'QTY_SEAICE_AGREG_SURFACETEMP')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:916:0:
#
#   916 | obs_kind_names(357) = obs_kind_type(QTY_SEAICE_AGREG_FREEBOARD,'QTY_SEAICE_AGREG_FREEBOARD')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:917:0:
#
#   917 | obs_kind_names(358) = obs_kind_type(QTY_SEAICE_CATEGORY,       'QTY_SEAICE_CATEGORY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:919:0:
#
#   919 | obs_kind_names(360) = obs_kind_type(QTY_SEA_SURFACE_ANOMALY,   'QTY_SEA_SURFACE_ANOMALY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:920:0:
#
#   920 | obs_kind_names(361) = obs_kind_type(QTY_LARGE_SCALE_STATE,     'QTY_LARGE_SCALE_STATE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:921:0:
#
#   921 | obs_kind_names(362) = obs_kind_type(QTY_SMALL_SCALE_STATE,     'QTY_SMALL_SCALE_STATE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:922:0:
#
#   922 | obs_kind_names(363) = obs_kind_type(QTY_CWP_PATH,              'QTY_CWP_PATH')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:923:0:
#
#   923 | obs_kind_names(364) = obs_kind_type(QTY_CWP_PATH_ZERO,         'QTY_CWP_PATH_ZERO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:924:0:
#
#   924 | obs_kind_names(365) = obs_kind_type(QTY_ION_O_MIXING_RATIO,    'QTY_ION_O_MIXING_RATIO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:925:0:
#
#   925 | obs_kind_names(366) = obs_kind_type(QTY_ATOMIC_H_MIXING_RATIO, 'QTY_ATOMIC_H_MIXING_RATIO')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:928:0:
#
#   928 | obs_kind_names(367) = obs_kind_type(QTY_PFLOTRAN_TEMPERATURE, 'QTY_PFLOTRAN_TEMPERATURE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:929:0:
#
#   929 | obs_kind_names(368) = obs_kind_type(QTY_PFLOTRAN_PERMEABILITY, 'QTY_PFLOTRAN_PERMEABILITY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:930:0:
#
#   930 | obs_kind_names(369) = obs_kind_type(QTY_PFLOTRAN_POROSITY, 'QTY_PFLOTRAN_POROSITY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:931:0:
#
#   931 | obs_kind_names(370) = obs_kind_type(QTY_PFLOTRAN_THERMALCONDUCTIVITY, 'QTY_PFLOTRAN_THERMALCONDUCTIVITY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:932:0:
#
#   932 | obs_kind_names(371) = obs_kind_type(QTY_PFLOTRAN_LIQUID_SATURATION, 'QTY_PFLOTRAN_LIQUID_SATURATION')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:933:0:
#
#   933 | obs_kind_names(372) = obs_kind_type(QTY_PFLOTRAN_LIQUID_PRESSURE, 'QTY_PFLOTRAN_LIQUID_PRESSURE')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:934:0:
#
#   934 | obs_kind_names(373) = obs_kind_type(QTY_PFLOTRAN_FLOWFLUX, 'QTY_PFLOTRAN_FLOWFLUX')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:935:0:
#
#   935 | obs_kind_names(374) = obs_kind_type(QTY_PFLOTRAN_THERMAL_CONDUCTIVITY, 'QTY_PFLOTRAN_THERMAL_CONDUCTIVITY')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# ../../../assimilation_code/modules/observations/obs_kind_mod.f90:936:0:
#
#   936 | obs_kind_names(375) = obs_kind_type(QTY_PFLOTRAN_FLOW_FLUX, 'QTY_PFLOTRAN_FLOW_FLUX')
#       |
# Error: Function 'obs_kind_names' at (1) has no IMPLICIT type
# make: *** [Makefile:70: obs_kind_mod.o] Error 1
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-28-8c74c0b8b3b8> in <module>
# ----> 1 get_ipython().run_cell_magic('script', 'bash -s "$work_dir" "$compile_model_check_mod"', 'cd $1\ncsh $2\n')
#
# /usr/local/anaconda3/envs/geosci/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# -> 2359                 result = fn(*args, **kwargs)
#    2360             return result
#    2361
#
# </usr/local/anaconda3/envs/geosci/lib/python3.7/site-packages/decorator.py:decorator-gen-110> in shebang(self, line, cell)
#
# /usr/local/anaconda3/envs/geosci/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/anaconda3/envs/geosci/lib/python3.7/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'cd $1\ncsh $2\n'' returned non-zero exit status 1.

# %% [markdown]
# # (TODO) Run DART and PFLOTRAN
# In this section, run the shell script to couple DART and PFLOTRAN

# %%
# %%script bash -s "$work_dir" "$run_filter"
# cd $1
# csh $2
